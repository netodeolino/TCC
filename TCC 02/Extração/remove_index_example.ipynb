# %%
import pandas

# %%
tes = pandas.read_csv("04.csv")

# %%
tes
# Out:
#     FONTE                             NATUREZA DA OCORRÊNCIA  \
# 0   CIOPS                                MORTE A BALA  06H00
# 1   CIOPS                                MORTE A BALA  08H45
# 2   CIOPS                     MORTE A BALA (FLAGRANTE) 10H08
# 3   CIOPS                                MORTE A BALA  20H45
# 4   CIOPS                              MORTE A OUTROS  21H52
# 5   CIOPS                                MORTE A BALA  23H03
# 6   CIOPS  PORTE ILEGAL DE ARMA /TRÁFICO DE ENTORPECENTES...
# 7   CIOPS  PORTE ILEGAL DE ARMA/ TRÁFICO DE ENTORPECENTES...
# 8   CIOPS  ROUBO A PESSOA/PORTE ILEGAL DE ARMA (FLAGRANTE...
# 9   CIOPS             PORTE ILEGAL DE ARMA (FLAGRANTE) 21H45
# 10  CIOPS   TRÁFICO DE ENTORPECENTES (ATO INFRACIONAL) 11H07
# 11  CIOPS            CONSUMO DE ENTORPECENTES (T.C.O.) 11H37
# 12  CIOPS         TRÁFICO DE ENTORPECENTES (FLAGRANTE) 13H58
# 13  CIOPS                          APREENSÃO DE DROGAS 17H53
# ...

# %%
tes.to_csv("./novo-tabula.csv", index=False)
