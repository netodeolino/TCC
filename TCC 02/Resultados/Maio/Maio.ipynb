# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df_maio = pandas.read_csv("./data/Cluster-Crime-Maio.csv")

# %%
crime_tipos = df_maio[['NATUREZA DA OCORRÊNCIA']]
crime_tipo_total = crime_tipos.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_tipo_counts = df_maio[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_tipo_counts['TOTAL'] = crime_tipo_total
all_crime_tipos = crime_tipo_counts.sort_values(by='TOTAL', ascending=False)

# %% [markdown]
# ### Filtro dos 10 crimes com mais ocorrências em maio

# %%
all_crime_tipos.head(10)
# Out:
#                                          TOTAL
# NATUREZA DA OCORRÊNCIA
# VEÍCULO LOCALIZADO                         218
# MORTE A BALA                                94
# PORTE ILEGAL DE ARMA                        45
# TRÁFICO DE ENTORPECENTES                    24
# ROUBO A PESSOA                              13
# PESSOA EM SITUAÇÃO SUSPEITA                  6
# VEÍCULOS LOCALIZADOS                         5
# MORTE A FACA                                 4
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)       4
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)      4

# %%
all_crime_tipos_top10 = all_crime_tipos.head(10)
all_crime_tipos_top10.plot(kind='barh', figsize=(12,6), color='#3f3fff')
plt.title('Top 10 crimes por tipo (Mai 2017)')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Todas as ocorrências criminais de maio

# %%
all_crime_tipos
# Out:
#                                                     TOTAL
# NATUREZA DA OCORRÊNCIA
# VEÍCULO LOCALIZADO                                    218
# MORTE A BALA                                           94
# PORTE ILEGAL DE ARMA                                   45
# TRÁFICO DE ENTORPECENTES                               24
# ROUBO A PESSOA                                         13
# PESSOA EM SITUAÇÃO SUSPEITA                             6
# VEÍCULOS LOCALIZADOS                                    5
# MORTE A FACA                                            4
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)                  4
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)                 4
# TRÁFICO DE ENTORPECENTES (ATO INFRACIONAL)              4
# CUMPRIMENTO DE MANDADO JUDICIAL                         4
# VEICULO LOCALIZADO                                      4
# MORTES A BALA                                           3
# MORTE - A BALA                                          3
# VEÍCULO LOCALIZADO(ATO INFRACIONAL)                     3
# PORTE ILEGAL DE ARMA(ATO INFRACIONAL)                   3
# TRÁFICO DE ENTORPECENTE                                 3
# FURTO A RESIDÊNCIA                                      3
# VEÍCULO LOCALIZADO (ATO INFRACIONAL)                    3
# APREENSÃO DE ARMA                                       3
# ABANDONO DE MATERIAL OU BENS MÓVEIS / ARMA APRE...      2
# TRÁFICO DE ENTORPECENTES (AUTO DE APREENSÃO)            2
# TENTATIVA DE FURTO                                      2
# ROUBO A PESSOA / ARMA APREENDIDA                        2
# MORTE A OUTROS                                          2
# TRÁFICO DE ENTORPECENTES / PORTE ILEGAL DE ARMA         2
# FURTO A PESSOA                                          2
# ARMA APREENDIDA                                         2
# ATROPELAMENTO NÃO FATAL                                 2
# ...                                                   ...
# ABANDONO DE MATERIAL OU BENS MÓVEIS ARMA APREEN...      1
# ABANDONO DE MATERIAL OU BENS MÓVEIS / ARMA APRE...      1
# MORTES A BALA LESÕES CORPORAIS A BALA                   1
# MORTES A BALASEGUIDO DO LESÃO CORPORAL                  1
# ROUBO A COLETIVO (FLAGRANTE / ATO INFRACIONAL)          1
# PORTE ILEGAL DE                                         1
# ROUBO A COLETIVO  (ATO INFRACIONAL)                     1
# ROUBO - A PESSOA                                        1
# ROUBO  A COLETIVO (FLAGRANTE / AUTO DE APREENSÃO)       1
# ROUBO  A COLETIVO                                       1
# POSSE ILEGAL DE ARMA BRANCA (TCO)                       1
# PORTE ILEGAL DE ARMA/TRÁFICO DE ENTORPECENTES           1
# PORTE ILEGAL DE ARMA ATO INFRACIONAL                    1
# PORTE ILEGAL DE ARMA / VEÍCULO LOCALIZADO  (ATO...      1
# PORTE ILEGAL DE ARMA / TRAFICO DE ENTORPECENTES         1
# PORTE ILEGAL DE ARMA / ATO INFRACIONAL                  1
# PORTE ILEGAL DE ARMA / APREENSÃO DE ENTORPECENTES       1
# PORTE ILEGAL DE ARMA / APREENSÃO DE ENTORPECENT...      1
# PORTE ILEGAL DE ARMA / APREENSÃO DE ENTORPECENTE        1
# PORTE ILEGAL DE ARMA /  TRÁFICO DE ENTORPECENTES        1
# PORTE ILEGAL DE ARMA (FLAGRANTE E AUTO DE APREE...      1
# PORTE ILEGAL DE ARMA (FLAGRANTE / ATO INFRACIONAL)      1
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL / FLAGRANTE)      1
# PORTE ILEGAL DE ARMA (ARMAS APREENDIDAS / FLAGR...      1
# PORTE ILEGAL DE ARMA  (FLAGRANTE / AUTO DE APRE...      1
# PORTE ILEGAL DE ARMA  (FLAGRANTE / ATO INFRACIO...      1
# PORTE ILEGAL DE ARMA  (FLAGRANTE /  AUTO DE APR...      1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL / FLAGRA...      1
# PORTE ILEGAL DE ARMA   (ATO INFRACIONAL)                1
# PORTE ILEGAL DE ARMA DUAS ARMAS / B.O. / FLAGRANTE      1
#
# [125 rows x 1 columns]

# %% [markdown]
# ### Quantidade de crimes por região

# %%
group_df_maio = df_maio.groupby('CLUSTER')
crimes = group_df_maio['NATUREZA DA OCORRÊNCIA'].count()

# %%
crimes.plot(kind='barh', figsize=(10,7), color='#3f3fff')
plt.title('Número de crimes por região (Mai 2017)')
plt.xlabel('Número')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### As 5 regiões com mais ocorrências

# %%
regioes = df_maio.groupby('CLUSTER').count()
grupo_de_regioes = regioes.sort_values('NATUREZA DA OCORRÊNCIA', ascending=False)

# %%
grupo_de_regioes['TOTAL'] = grupo_de_regioes.ID
top_5_regioes_qtd = grupo_de_regioes.TOTAL.head(6)

# %%
top_5_regioes_qtd.plot(kind='barh', figsize=(10,4), color='#3f3fff')
plt.title('Top 5 regiões com mais crimes')
plt.xlabel('Número de crimes')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Acima podemos ver que a região 4 teve o maior número de ocorrências criminais

# %% [markdown]
# ### Podemos agora ver quais são essas ocorrências de forma mais detalhada

# %%
regiao_4_detalhe = df_maio[df_maio['CLUSTER'] == 4]
regiao_4_detalhe
# Out:
#       ID  FONTE FLAGRANTE                             NATUREZA DA OCORRÊNCIA  \
# 8      9  CIOPS       NÃO  PORTE ILEGAL DE ARMA (ATO INFRACIONAL / FLAGRA...
# 48    49  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 52    53  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 61    62  CIOPS       NÃO                                       MORTE A BALA
# 68    69  CIOPS       NÃO         TRÁFICO DE ENTORPECENTES (ATO INFRACIONAL)
# 90    91  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 95    96  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 100  101  CIOPS       NÃO                                       MORTE A BALA
# 103  104  CIOPS       NÃO                                       MORTE A BALA
# 109  110  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 138  139  CIOPS       SIM                                  ROUBO  A COLETIVO
# 146  147  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 156  157  CIOPS       NÃO                                       MORTE A BALA
# 206  207  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 207  208  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 215  216  CIOPS       NÃO                     MORTE A BALA   ARMA APREENDIDA
# 220  221  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 226  227  CIOPS       NÃO                              EMBRIAGUEZ AO VOLANTE
# 230  231  CIOPS       NÃO                                       MORTE A BALA
# 253  254  CIOPS       NÃO            PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)
# 254  255  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 265  266  CIOPS       SIM                                 VEÍCULO LOCALIZADO
# 274  275  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 300  301  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 309  310  CIOPS       NÃO                                       MORTE A BALA
# 312  313  CIOPS       NÃO                                       MORTE A BALA
# 333  334  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 349  350  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 380  381  CIOPS       NÃO                                       MORTE A BALA
# 384  385  CIOPS       NÃO  MORTE A BALA / ARMAS APREENDIDAS (ATO INFRACIO...
# 401  402  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 420  421  CIOPS       NÃO       TRÁFICO DE ENTORPECENTES (AUTO DE APREENSÃO)
# 441  442  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 496  497  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 506  507  CIOPS       NÃO          TRÁFICO DE ENTORPECENTE (ATO INFRACIONAL)
# 509  510  CIOPS       SIM                            TRÁFICO DE ENTORPECENTE
# 515  516  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 516  517  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
# 533  534  CIOPS       SIM                           TRÁFICO DE ENTORPECENTES
# 553  554  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 561  562  CIOPS       NÃO                                 VEÍCULO LOCALIZADO
#
#                                HISTÓRICO DA OCORRÊNCIA  \
# 8    LOCAL: RUA PARAISO, PASSARÉ. SUSPEITOS: 1°MENO...
# 48   LOCAL: AV. PERIMETRAL, JANGURUSSU.  VEÍCULO: P...
# 52   LOCAL: RUA ELDORADO, PASSARÉ. VEÍCULO: HILUXSW...
# 61   LOCAL: AV. PRESIDENTE COSTA E SILVA, PASSARÉ. ...
# 68   LOCAL: RUA MAÍZA, JANGURUSSÚ. SUSPEITO: MENOR ...
# 90   LOCAL: RUA RITA C, JOÃO PAULO II, MESSEJANA. V...
# 95   LOCAL: RUA TRÊS, 210, PASSARÉ. VEÍCULO: SIENA ...
# 100  LOCAL: RUA CONDE SANDOVAL, JANGURUSSÚ. VÍTIMA:...
# 103  LOCAL: RUA VINTE E TRÊS, BARROSO. VÍTIMA: FRAN...
# 109  LOCAL: RUA ALCIDES GERARDI, CONJUNTO PALMEIRAS...
# 138  LOCAL: AV. PERIMETRAL, PICI.  TRÊS SUSPEITOS Q...
# 146  LOCAL: RUA 305, CONJUNTO CEARÁ.  VEÍCULO: GOL ...
# 156  LOCAL: RUA TRÊS CORAÇÕES, PASSARÉ. VÍTIMA: PAU...
# 206  LOCAL: RUA H, MARAPONGA. VEÍCULO: PRISMA, CINZ...
# 207  LOCAL: RUA L, BARROSO.VEÍCULO: XRE300 BRANCA P...
# 215  LOCAL: RUA DOS LÍRIOS, BARROSO.  VÍTIMA: CARLO...
# 220  LOCAL: RUA C, JARDIM CASTELÃO.  ARMA APREENDID...
# 226  LOCAL: AV. CASTELO DE CASTRO, JANGURUSSU.VEÍCU...
# 230  LOCAL: RUA SEIS, PASSARÉ. VÍTIMA: MENOR DE IDA...
# 253  LOCAL:AV.GOVERNADORLEONELBRISOLA,JANGURUSSU.AR...
# 254  LOCAL: RUA DIAMANTE, PASSARÉ.SUSPEITOS: 1o ROB...
# 265  LOCAL: AV. JUSCELINO KUBITSCHEK, PASSARÉ.VEÍCU...
# 274  LOCAL: AV. MONSENHOR AMAURILO RODRIGUES, JANGU...
# 300  LOCAL: RUA TOPAZIO, BARROSO.  VEÍCULO: CG 160 ...
# 309  LOCAL: AV. CASTELO DE CASTRO, JANGURUSSU.  VÍT...
# 312  LOCAL: RUA EMILIANO ALMEIDA BRAGA, BARROSO.  V...
# 333  LOCAL: RUA DUZENTOS E DOIS, JANGURUSSU.  VEÍCU...
# 349  LOCAL: RUA DUZENTOS E SEIS, JANGURUSSÚ. VEICUL...
# 380  LOCAL: RUA QUATORZE, BARROSO. VÍTIMA: GLEIDSON...
# 384  LOCAL: RUA SAFIRA, BARROSO. VÍTIMA: MENOR DE I...
# 401  LOCAL: RUA ESTRADA DO ITAPERI, PASSARÉ. VEÍCUL...
# 420  LOCAL: PRAÇA DO CONJUNTO JOAO PAULO II. SUSPEI...
# 441  LOCAL: RUA MAISA, CONJUNTO PALMEIRAS. SUSPEITO...
# 496  LOCAL: AV. PADARIA ESPIRITUAL, PASSARÉ.ARMA AP...
# 506  LOCAL:AV.GOVERNADORLEONELBRIZOLA,JANGURUSSÚ.MA...
# 509  LOCAL: AV. JUCELINOKUBITSCHEK, PASSARÉ. MATERI...
# 515  LOCAL: RUA SANTA RITA, CONJUNTO PALMEIRAS.  VE...
# 516  LOCAL: RUA DOIS, PASSARÉ.  VEÍCULO: PALIO ATTR...
# 533  LOCAL:RUABELAVISTA,JANGURUSSU.SUSPEITO:JOÃOPAU...
# 553  LOCAL:RUAANGELODINIZ,CONJUNTOPALMEIRAS.SUSPEIT...
# 561  LOCAL: AV. CASTELO DE CASTRO, JANGURUSSU.  VEÍ...
#
#                                            LOCAL:  \
# 8                            RUA PARAISO, PASSARÉ
# 48                     AV. PERIMETRAL, JANGURUSSU
# 52                          RUA ELDORADO, PASSARÉ
# 61          AV. PRESIDENTE COSTA E SILVA, PASSARÉ
# 68                          RUA MAÍZA, JANGURUSSÚ
# 90           RUA RITA C, JOÃO PAULO II, MESSEJANA
# 95                         RUA TRÊS, 210, PASSARÉ
# 100                RUA CONDE SANDOVAL, JANGURUSSÚ
# 103                     RUA VINTE E TRÊS, BARROSO
# 109       RUA ALCIDES GERARDI, CONJUNTO PALMEIRAS
# 138                          AV. PERIMETRAL, PICI
# 146                       RUA 305, CONJUNTO CEARÁ
# 156                    RUA TRÊS CORAÇÕES, PASSARÉ
# 206                              RUA H, MARAPONGA
# 207                                RUA L, BARROSO
# 215                       RUA DOS LÍRIOS, BARROSO
# 220                        RUA C, JARDIM CASTELÃO
# 226             AV. CASTELO DE CASTRO, JANGURUSSU
# 230                             RUA SEIS, PASSARÉ
# 253         AV.GOVERNADORLEONELBRISOLA,JANGURUSSU
# 254                         RUA DIAMANTE, PASSARÉ
# 265             AV. JUSCELINO KUBITSCHEK, PASSARÉ
# 274  AV. MONSENHOR AMAURILO RODRIGUES, JANGURUSSÚ
# 300                          RUA TOPAZIO, BARROSO
# 309             AV. CASTELO DE CASTRO, JANGURUSSU
# 312           RUA EMILIANO ALMEIDA BRAGA, BARROSO
# 333               RUA DUZENTOS E DOIS, JANGURUSSU
# 349               RUA DUZENTOS E SEIS, JANGURUSSÚ
# 380                         RUA QUATORZE, BARROSO
# 384                           RUA SAFIRA, BARROSO
# 401               RUA ESTRADA DO ITAPERI, PASSARÉ
# 420               PRAÇA DO CONJUNTO JOAO PAULO II
# 441                 RUA MAISA, CONJUNTO PALMEIRAS
# 496               AV. PADARIA ESPIRITUAL, PASSARÉ
# 506         AV.GOVERNADORLEONELBRIZOLA,JANGURUSSÚ
# 509               AV. JUCELINOKUBITSCHEK, PASSARÉ
# 515            RUA SANTA RITA, CONJUNTO PALMEIRAS
# 516                             RUA DOIS, PASSARÉ
# 533                       RUABELAVISTA,JANGURUSSU
# 553              RUAANGELODINIZ,CONJUNTOPALMEIRAS
# 561             AV. CASTELO DE CASTRO, JANGURUSSU
#
#                               BAIRRO  \
# 8                            PASSARÉ
# 48                        JANGURUSSU
# 52                           PASSARÉ
# 61                           PASSARÉ
# 68                        JANGURUSSÚ
# 90          JOÃO PAULO II, MESSEJANA
# 95                      210, PASSARÉ
# 100                       JANGURUSSÚ
# 103                          BARROSO
# 109               CONJUNTO PALMEIRAS
# 138                             PICI
# 146                   CONJUNTO CEARÁ
# 156                          PASSARÉ
# 206                        MARAPONGA
# 207                          BARROSO
# 215                          BARROSO
# 220                  JARDIM CASTELÃO
# 226                       JANGURUSSU
# 230                          PASSARÉ
# 253                       JANGURUSSU
# 254                          PASSARÉ
# 265                          PASSARÉ
# 274                       JANGURUSSÚ
# 300                          BARROSO
# 309                       JANGURUSSU
# 312                          BARROSO
# 333                       JANGURUSSU
# 349                       JANGURUSSÚ
# 380                          BARROSO
# 384                          BARROSO
# 401                          PASSARÉ
# 420  PRAÇA DO CONJUNTO JOAO PAULO II
# 441               CONJUNTO PALMEIRAS
# 496                          PASSARÉ
# 506                       JANGURUSSÚ
# 509                          PASSARÉ
# 515               CONJUNTO PALMEIRAS
# 516                          PASSARÉ
# 533                       JANGURUSSU
# 553                CONJUNTOPALMEIRAS
# 561                       JANGURUSSU
#
#                                              SUSPEITO:  \
# 8                                                 nulo
# 48                                                nulo
# 52                                                nulo
# 61                                    NÃO IDENTIFICADO
# 68                                      MENOR DE IDADE
# 90                                                nulo
# 95                                                nulo
# 100                                               nulo
# 103                                               nulo
# 109                    DANIEL FERNANDES ANDRE, 31 ANOS
# 138                                               nulo
# 146                                               nulo
# 156                                               nulo
# 206                                               nulo
# 207                                               nulo
# 215                                   NÃO IDENTIFICADO
# 220  RAFAEL OLIVEIRA DO VALE, 32 ANOS, FOI CONDUZID...
# 226                                               nulo
# 230                                               nulo
# 253                                               nulo
# 254                                               nulo
# 265  RAUL JOSÉ DA SILVA GOES, 20 ANOS, FOI CONDUZID...
# 274                                               nulo
# 300                                               nulo
# 309                                               nulo
# 312                                               nulo
# 333                                               nulo
# 349                                               nulo
# 380                                               nulo
# 384                                     MENOR DE IDADE
# 401                                               nulo
# 420                                     MENOR DE IDADE
# 441                      FRANKLIN TERTO BRITO, 22 ANOS
# 496                                               nulo
# 506                                       MENORDEIDADE
# 509                                               nulo
# 515                                               nulo
# 516                                               nulo
# 533                            JOÃOPAULODASILVA,35ANOS
# 553                      PEDROHENRIQUEDOSSANTOS,20ANOS
# 561                                               nulo
#
#                                              VEÍCULO:         VÍTIMA:   ...    \
# 8                                                nulo            nulo   ...
# 48        PALIO YOUNG, VERMELHA, 01/01, PLACA HWH7065            nulo   ...
# 52          HILUXSW4 SRV4X4,BRANCA, 14/15, QGC0299-CE            nulo   ...
# 61                                               nulo       ROBÉRIO B   ...
# 68                                               nulo            nulo   ...
# 90                                       UNO VIVACE 1            nulo   ...
# 95                                  SIENA ATTRACTIV 1            nulo   ...
# 100                                              nulo         LUCAS M   ...
# 103                                              nulo     FRANCISCO J   ...
# 109                                              nulo            nulo   ...
# 138                                              nulo            nulo   ...
# 146                                          GOL GL 1            nulo   ...
# 156                                              nulo       PAULO RVM   ...
# 206                      PRISMA, CINZA, HYC 0276 - CE            nulo   ...
# 207                       XRE300 BRANCA PLACA PNN1451            nulo   ...
# 215                                              nulo        CARLOS A   ...
# 220                                              nulo            nulo   ...
# 226             PALIO WEEKEND AZUL DE PLACAS HWE-2000            nulo   ...
# 230                                              nulo  MENOR DE IDADE   ...
# 253                                              nulo            nulo   ...
# 254                                              nulo            nulo   ...
# 265           FAN KS, PRETA, 2012/2013, PLACA ORU3851            nulo   ...
# 274        YS150 FAZER ED, VERMELHA, 2015, PNN9016-CE            nulo   ...
# 300            CG 160 FAN, VERMELHA, 2016, PNP5968-CE            nulo   ...
# 309                                              nulo    MAURÍCIO V H   ...
# 312                                              nulo     ARISTÊNIO M   ...
# 333                                          VOYAGE 1            nulo   ...
# 349                                              nulo            nulo   ...
# 380                                              nulo     GLEIDSON RA   ...
# 384                                              nulo  MENOR DE IDADE   ...
# 401             207HB, PRATA, 2009, PLACA: NQM1759-CE            nulo   ...
# 420                                              nulo            nulo   ...
# 441                    CG150, PRETA, 2015, PME7434-CE            nulo   ...
# 496                                              nulo            nulo   ...
# 506                                              nulo            nulo   ...
# 509                                              nulo            nulo   ...
# 515  TUCSON GLSB, PRATA, 2012/2013, PLACA: OHY0379-CE            nulo   ...
# 516                                   PALIO ATTRACT 1            nulo   ...
# 533                                              nulo            nulo   ...
# 553                                              nulo            nulo   ...
# 561           DAILY55C16 CS, BRANCA, 2008, NRB6472-CE            nulo   ...
#
#     MATERIAL APREENDIDO:      PLACA: VÍTIMAS LESIONADAS:  \
# 8                   nulo        nulo                nulo
# 48                  nulo        nulo                nulo
# 52                  nulo        nulo                nulo
# 61                  nulo        nulo                nulo
# 68                  nulo        nulo                nulo
# 90                  nulo        nulo                nulo
# 95                  nulo        nulo                nulo
# 100                 nulo        nulo                nulo
# 103                 nulo        nulo                nulo
# 109                 nulo        nulo                nulo
# 138                 nulo        nulo                nulo
# 146                 nulo        nulo                nulo
# 156                 nulo        nulo                nulo
# 206                 nulo        nulo                nulo
# 207                 nulo        nulo                nulo
# 215                 nulo        nulo                nulo
# 220                 nulo        nulo                nulo
# 226                 nulo        nulo                nulo
# 230                 nulo        nulo                nulo
# 253                 nulo        nulo                nulo
# 254                 nulo        nulo                nulo
# 265                 nulo        nulo                nulo
# 274                 nulo        nulo                nulo
# 300                 nulo        nulo                nulo
# 309                 nulo        nulo                nulo
# 312                 nulo        nulo                nulo
# 333                 nulo        nulo                nulo
# 349                 nulo     PME1579                nulo
# 380                 nulo        nulo                nulo
# 384                 nulo        nulo                nulo
# 401                 nulo  NQM1759-CE                nulo
# 420              COCAÍNA        nulo                nulo
# 441                 nulo        nulo                nulo
# 496                 nulo        nulo                nulo
# 506                 nulo        nulo                nulo
# 509                CRACK        nulo                nulo
# 515                 nulo  OHY0379-CE                nulo
# 516                 nulo  ORO2546-CE                nulo
# 533                 nulo        nulo                nulo
# 553                 nulo        nulo                nulo
# 561                 nulo        nulo                nulo
#
#                                             SUSPEITOS: HORA MINUTO      DATA  \
# 8    1°MENOR DE IDADE; 2° FRANCISCO MARCELINO GOMES...   18     34  01/05/17
# 48                                                nulo   11     53  03/05/17
# 52                                                nulo   18     14  03/05/17
# 61                                                nulo   16     22  04/05/17
# 68                                                nulo   10     46  04/05/17
# 90                                                nulo   03     33  06/05/17
# 95                                                nulo   13     23  06/05/17
# 100                                  NÃO IDENTIFICADOS   19     00  07/05/17
# 103                                  NÃO IDENTIFICADOS   21     05  07/05/17
# 109                                               nulo   12     18  07/05/17
# 138                                               nulo   18     11  08/05/17
# 146                                               nulo   11     19  08/05/17
# 156                                  NÃO IDENTIFICADOS   18     09  09/05/17
# 206                                               nulo   07     50  11/05/17
# 207                                               nulo   11     22  11/05/17
# 215                                               nulo   16     51  12/05/17
# 220                                               nulo   11     49  12/05/17
# 226                                               nulo   20     55  12/05/17
# 230                        DOIS INDIVÍDUOS EM UMA MOTO   22     43  14/05/17
# 253                                               nulo   12     38  16/05/17
# 254               1o ROBERTO DE SOUSA RIBEIRO, 30 ANOS   13     42  16/05/17
# 265                                               nulo   21     48  16/05/17
# 274                                               nulo   09     23  18/05/17
# 300                                               nulo   08     24  19/05/17
# 309                                  NÃO IDENTIFICADOS   15     19  20/05/17
# 312                                  NÃO IDENTIFICADOS   21     47  20/05/17
# 333                                               nulo   19     09  20/05/17
# 349                                               nulo   14     09  21/05/17
# 380                                  NÃO IDENTIFICADOS   12     03  25/05/17
# 384                                               nulo   19     54  25/05/17
# 401                                               nulo   10     28  25/05/17
# 420                                               nulo   15     43  26/05/17
# 441                                               nulo   20     48  27/05/17
# 496  1o-GUILHERME DOS SANTOS VIDAL, 30 ANOS, 2o-JEF...   00     47  29/05/17
# 506                                               nulo   17     54  29/05/17
# 509  1o-VICTOR HUGO DA CRUZ PEREIRA, 20 ANOS, 2o-SA...   19     51  29/05/17
# 515                                               nulo   12     19  29/05/17
# 516                                               nulo   12     39  29/05/17
# 533                                               nulo   20     07  30/05/17
# 553                                               nulo   16     58  31/05/17
# 561                                               nulo   12     24  31/05/17
#
#      LATITUDE  LONGITUDE CLUSTER
# 8   -3.827550 -38.528965       4
# 48  -3.827647 -38.532800       4
# 52  -3.816488 -38.531592       4
# 61  -3.826825 -38.536459       4
# 68  -3.848035 -38.527801       4
# 90  -3.824237 -38.517758       4
# 95  -3.821459 -38.531319       4
# 100 -3.840835 -38.526164       4
# 103 -3.826175 -38.520645       4
# 109 -3.843721 -38.528667       4
# 138 -3.827647 -38.532800       4
# 146 -3.836277 -38.523060       4
# 156 -3.816792 -38.522897       4
# 206 -3.817400 -38.527368       4
# 207 -3.827272 -38.520528       4
# 215 -3.824320 -38.515608       4
# 220 -3.819646 -38.530007       4
# 226 -3.840861 -38.521850       4
# 230 -3.818705 -38.531351       4
# 253 -3.831674 -38.522958       4
# 254 -3.821514 -38.524219       4
# 265 -3.816554 -38.531966       4
# 274 -3.835189 -38.522848       4
# 300 -3.820879 -38.523096       4
# 309 -3.840861 -38.521850       4
# 312 -3.819806 -38.523830       4
# 333 -3.831657 -38.523588       4
# 349 -3.833276 -38.525205       4
# 380 -3.824324 -38.519354       4
# 384 -3.821599 -38.525708       4
# 401 -3.823407 -38.529905       4
# 420 -3.825987 -38.516052       4
# 441 -3.848035 -38.527801       4
# 496 -3.817902 -38.532628       4
# 506 -3.831674 -38.522958       4
# 509 -3.816554 -38.531966       4
# 515 -3.839163 -38.531008       4
# 516 -3.821966 -38.531604       4
# 533 -3.830650 -38.524978       4
# 553 -3.846700 -38.527242       4
# 561 -3.840861 -38.521850       4
#
# [41 rows x 23 columns]

# %% [markdown]
# ### Uma análise sobre as 5 ocorrências mais comuns

# %%
crime_types = regiao_4_detalhe[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = regiao_4_detalhe[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5 = all_crime_types.head(5)
crimes_top_5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes na região 4')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 horários com mais ocorrências em maio

# %%
horas_mes = df_maio.HORA.value_counts()
horas_mes_top10 = horas_mes.head(10)

# %%
horas_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Crimes por hora (Mai 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 5 horários com mais ocorrências na região 4 (região com mais ocorrências em maio)

# %%
crime_hours = regiao_4_detalhe[['HORA']]
crime_hours_total = crime_hours.groupby('HORA').size()
crime_hours_counts = regiao_4_detalhe[['HORA']].groupby('HORA').sum()
crime_hours_counts['TOTAL'] = crime_hours_total
all_hours_types = crime_hours_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_hours_types.head(5)
# Out:
#       TOTAL
# HORA
# 12        6
# 19        4
# 11        4
# 18        4
# 21        3

# %%
all_hours_types_top5 = all_hours_types.head(5)
all_hours_types_top5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes por hora na região 4')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 bairros com mais ocorrências em maio

# %%
crimes_mes = df_maio.BAIRRO.value_counts()
crimes_mes_top10 = crimes_mes.head(10)

# %%
crimes_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Top 10 Bairros com mais crimes (Mai 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### O Bairro com o maior número de ocorrências em janeiro foi o Barra do Ceará

# %% [markdown]
# ### Vamos agora ver de forma mais detalhadas quais foram estes crimes

# %%
barra_do_ceara = df_maio[df_maio['BAIRRO'] == 'BARRA DO CEARÁ']
crime_types = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes na Barra do Ceará')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Os 5 bairros mais comuns na região 4

# %%
crime_types_bairro = regiao_4_detalhe[['BAIRRO']]
crime_type_total_bairro = crime_types_bairro.groupby('BAIRRO').size()
crime_type_counts_bairro = regiao_4_detalhe[['BAIRRO']].groupby('BAIRRO').sum()
crime_type_counts_bairro['TOTAL'] = crime_type_total_bairro
all_crime_types_bairro = crime_type_counts_bairro.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5_bairro = all_crime_types_bairro.head(5)
crimes_top_5_bairro.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 bairros na região 4')
plt.xlabel('Quantidade')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Análise sobre o bairro Passaré

# %%
passare = df_maio[df_maio['BAIRRO'] == 'PASSARÉ']
crime_types = passare[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = passare[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes no Passaré')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
