# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df_janeiro = pandas.read_csv("./data/Cluster-Crime-Janeiro.csv")

# %%
crime_tipos = df_janeiro[['NATUREZA DA OCORRÊNCIA']]
crime_tipo_total = crime_tipos.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_tipo_counts = df_janeiro[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_tipo_counts['TOTAL'] = crime_tipo_total
all_crime_tipos = crime_tipo_counts.sort_values(by='TOTAL', ascending=False)

# %% [markdown]
# ### Filtro dos 10 crimes com mais ocorrências em janeiro

# %%
all_crime_tipos.head(10)
# Out:
#                                              TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                             196
# MORTE A BALA                                    64
# PORTE ILEGAL DE ARMA                            34
# TRAFICO DE ENTORPECENTES                        27
# ROUBO A PESSOA                                  12
# TRAFICO DE ENTORPECENTE                          9
# TRAFICO DE ENTORPECENTES  (ATO INFRACIONAL)      8
# MORTE A OUTROS                                   7
# ROUBO A PESSOA (ATO INFRACIONAL)                 5
# VEICULO LOCALIZADO (ATO INFRACIONAL)             5

# %%
all_crime_tipos_top10 = all_crime_tipos.head(10)
all_crime_tipos_top10.plot(kind='barh', figsize=(12,6), color='#3f3fff')
plt.title('Top 10 crimes por tipo (Jan 2017)')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Todas as ocorrências criminais de janeiro

# %%
all_crime_tipos
# Out:
#                                                     TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                                    196
# MORTE A BALA                                           64
# PORTE ILEGAL DE ARMA                                   34
# TRAFICO DE ENTORPECENTES                               27
# ROUBO A PESSOA                                         12
# TRAFICO DE ENTORPECENTE                                 9
# TRAFICO DE ENTORPECENTES  (ATO INFRACIONAL)             8
# MORTE A OUTROS                                          7
# ROUBO A PESSOA (ATO INFRACIONAL)                        5
# VEICULO LOCALIZADO (ATO INFRACIONAL)                    5
# CUMPRIMENTO DE MANDADO JUDICIAL                         4
# ROUBO A COLETIVO                                        4
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)                 4
# MORTE A FACA                                            4
# AMEACA                                                  4
# TRAFICO DE ENTORPECENTE  (ATO INFRACIONAL)              3
# ROUBO DE VEICULO                                        3
# MORTES A BALA                                           3
# ROUBO A COLETIVO (ATO INFRACIONAL)                      3
# LESAO CORPORAL                                          3
# RECEPTACAO                                              3
# LESAO CORPORAL A OUTROS                                 3
# ROUBO A PESSOA / PORTE ILEGAL DE ARMA                   2
# LESAO CORPORAL A FACA                                   2
# ROUBO DE VEICULO SEGUIDO DE LOCALIZACAO                 2
# MORTE  A BALA                                           2
# MORTE A BALA / ARMA APREENDIDA                          2
# FURTO A ESTABELECIMENTO                                 2
# ABANDONO DE MATERIAL OU BENS MOVEIS                     2
# TENTATIVA DE ROUBO                                      2
# ...                                                   ...
# FURTO A ESTABELECIMENTO COMERCIAL                       1
# FURTO A PESSOA                                          1
# PORTE ILEGAL DE ARMA / TRAFICO DE ENTORPECENTES...      1
# PORTE ILEGAL DE ARMA / TRAFICO DE ENTORPECENTES...      1
# PORTE ILEGAL DE ARMA / ROUBO DE VEICULO                 1
# PORTE ILEGAL DE ARMA / FORMACAO DE QUADRILHA / ...      1
# PORTE ILEGAL DE ARMA (FLAGRANTE / ATO INFRACIONAL)      1
# PORTE ILEGAL DE ARMA (BOC)                              1
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)                  1
# ABANDONO DE MATERIAL OU BENS MOVEIS / ARMA APRE...      1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL/FLAGRANTE)       1
# PESSOAS EM SITUACAO SUSPEITA                            1
# PESSOA / SITUACAO SUSPEITA / 03 VEICULOS APREEN...      1
# PERTURBACAO AO SOSSEGO ALHEIO - EM CARRO (T.C.O.)       1
# MORTE A BALA SEGUIDO DE LESAO CORPORAL                  1
# MORTE A BALA SEGUIDO DE LESAO A BALA                    1
# MORTE A BALA SEGUIDA DE LESAO CORPORAL A BALA           1
# MORTE A BALA LESAO CORPORAL A  BALA                     1
# MORTE A BALA / VEICULO LOCALIZADO                       1
# MORTE A BALA / TENTATIVA DE ROUBO /  ARMA APREE...      1
# MORTE A BALA / SEGUIDA DE LESÕES CORPORAIS A BALA       1
# MORTE A BALA / LESAO CORPORAL A BALA / TENTATIV...      1
# MORTE A BALA (ARMA APREENDIDA/VEICULO LOCALIZADO)       1
# MORTE A BALA (ARMA APREENDIDA/FLAGRANTE)                1
# MORTE A BALA (ARMA APREENDIDA)                          1
# MORTE A BALA  (FLAGRANTE / ARMA APREENDIDA)             1
# MORTE A BALA  (ARMA APREENDIDA)                         1
# LESAO CORPORAL A BALA /PORTE ILEGAL DE ARMAS            1
# LESAO CORPORAL A BALA                                   1
# VEICULOS LOCALIZADOS                                    1
#
# [143 rows x 1 columns]

# %% [markdown]
# ### Quantidade de crimes por região

# %%
group_df_janeiro = df_janeiro.groupby('CLUSTER')
crimes = group_df_janeiro['NATUREZA DA OCORRÊNCIA'].count()

# %%
crimes.plot(kind='barh', figsize=(10,7), color='#3f3fff')
plt.title('Número de crimes por região (Jan 2017)')
plt.xlabel('Número')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### As 5 regiões com mais ocorrências

# %%
regioes = df_janeiro.groupby('CLUSTER').count()
grupo_de_regioes = regioes.sort_values('NATUREZA DA OCORRÊNCIA', ascending=False)

# %%
grupo_de_regioes['TOTAL'] = grupo_de_regioes.ID
top_5_regioes_qtd = grupo_de_regioes.TOTAL.head(6)

# %%
top_5_regioes_qtd.plot(kind='barh', figsize=(10,4), color='#3f3fff')
plt.title('Top 5 regiões com mais crimes')
plt.xlabel('Número de crimes')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Acima podemos ver que a região 4 teve o maior número de ocorrências criminais

# %% [markdown]
# ### Podemos agora ver quais são essas ocorrências de forma mais detalhada

# %%
regiao_4_detalhe = df_janeiro[df_janeiro['CLUSTER'] == 4]
regiao_4_detalhe
# Out:
#       ID  FONTE FLAGRANTE                             NATUREZA DA OCORRÊNCIA  \
# 20    21  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 25    26  CIOPS       SIM                                     ROUBO A PESSOA
# 30    31  CIOPS       NÃO                                 VEICULO LOCALIZADO
#
# 419            RUA DEMETRIO MENEZES, ANTONIO BEZERRA  ANTONIO BEZERRA
# 438                     RUA CURITIBA, HENRIQUE JORGE   HENRIQUE JORGE
# 441                              RUA NOEL ROSA, PICI             PICI
# 442                  RUA EDGARD ARRUDA, JOQUEI CLUBE     JOQUEI CLUBE
# 460             RUA CIDADE DO RIO BRANCO, JOAO XXIII       JOAO XXIII
# 461                       TRAVESSA CONSELHEIRO, PICI             PICI
# 481                  RUA ELESBAO VELOSO, DOM LUSTOSA      DOM LUSTOSA
# 483                   RUA PEDRO AUGUSTO, DOM LUSTOSA      DOM LUSTOSA
# 497              RUA HIPOLITO BRASIL, HENRIQUE JORGE   HENRIQUE JORGE
# 505                         TV MONTEIRO LOBATO, PICI             PICI
# 530                RUA MARTINS NETO, ANTONIO BEZERRA  ANTONIO BEZERRA
#
#                                              SUSPEITO:  \
# 20                       ARILSON SILVA XAVIER, 18 ANOS
# 25                                                nulo
# 30                                                nulo
# 34                                                nulo
# 39                                                nulo
# 45                   JUSCIER SARAIVA DA SILVA, 29 ANOS
# 46              GLEICIANO DOS SANTOS DE ASSIS, 18 ANOS
# 50                                                nulo
# 51                                                nulo
# 60                             HOMEM NÃO IDENTIFICADOS
# 80                                                nulo
# 84   MENOR DE IDADE, CONDUZIDO À\nDELEGACIA COMPETENTE
# 106                                               nulo
# 110                                               nulo
# 131                                               nulo
# 142                                               nulo
# 152                                               nulo
# 156                                               nulo
# 168                                   NÃO IDENTIFICADO
# 175                       LUIZ LOPES DE SOUZA, 18 ANOS
# 176                                     MENOR DE IDADE
# 194                                               nulo
# 202  JOABSON LIMA SABINO 22 ANOS, FO\nCONDUZIDO À D...
# 229                                               nulo
# 233                                               nulo
# 234                                               nulo
# 241                                   NÃO IDENTIFICADO
# 246                                               nulo
# 250                                               nulo
# 270  MENOR DE IDADE,\nCONDUZIDA À DELEGACIA COMPETENTE
# ..                                                 ...
# 301                                               nulo
# 310                                               nulo
# 312                                               nulo
# 314                                               nulo
# 316   MENOR DE IDADE, CONDUZIDO À DELEGACIA COMPETENTE
# 334                    DEIVID DUARTE DE SOUSA, 24 ANOS
# 345                   MICKAELBRUNOPEREIRADELIMA,21ANOS
# 363                                               nulo
# 365                                               nulo
# 376                                               nulo
# 385                                               nulo
# 388                                               nulo
# 390                                               nulo
# 393                                   NÃO IDENTIFICADO
# 401                                               nulo
# 404                                               nulo
# 406                                               nulo
# 412                                               nulo
# 416  SANTIAGODASILVAPEREIRA,32ANOS,FOI\nCONDUZIDO À...
# 419                                               nulo
# 438                                               nulo
# 441                                               nulo
# 442                                               nulo
# 460                                               nulo
# 461                                     MENOR DE IDADE
# 481                                               nulo
# 483                                               nulo
# 497                                               nulo
# 505                                               nulo
# 530                                               nulo
#
#                                             VEÍCULO:  \
# 20                                              nulo
# 25                                              nulo
# 30            ETIOS SD X, VERMELHA, 2014, OSA2480-CE
# 34         SIENA FIRE FLEX, CINZA, 08/09, HYE5806-CE
# 39                                              nulo
# 45                                              nulo
# 46                                              nulo
# 50   ETIOS SD XLS, BRANCA, 2013/2014, PLACAS OSO3357
# 51                                       PARATI CL 1
# 60                                              nulo
# 80        UNO ECONOMY, PRETA, 2011/2012, OCC 5140-CE
# 84    CG 125 FAN KS, PRETA, 2013/2014, PLACA OSJ7547
# 106              BROS ESD, PRETA, 14/15, PML 1908-CE
# 110             CINQUETINHA, VERMELHA, MARC A JHONNY
# 131      FAN ESI, VERMELHA, 11/12, PLACA: OCD7977-CE
# 142                                             nulo
# 152                                             nulo
# 156                                             nulo
# 168                                             nulo
# 175                                             nulo
# 176                                             nulo
# 194                                             nulo
# 202       CG 150 TITAN EX, BRANCA, 14/15, PML8020-CE
# 229                                             nulo
# 233                                            GOL 1
# 234             SPACEFOX, 2007, PRATA, PLACA HWQ0454
# 241                                             nulo
# 246                                             nulo
# 250     BROS, VERMELHA, 2016/2016, PLACA: PNM4326-CE
# 270                 XRE 300, VERMELHA,11, OCE0645-CE
# ..                                               ...
# 301                  CORSA, BRANCA, 1996, HUZ2313-CE
# 310                                             nulo
# 312                                             nulo
# 314                                             nulo
# 316                                             nulo
# 334                                             nulo
# 345                                             nulo
# 363                                             nulo
# 365                                             nulo
# 376           PALIO FIRE ECONOMY, PRATA, 12, OIQ6091
# 385                       CG FAN 150, VINHO, NUR8040
# 388                                             nulo
# 390                                             nulo
# 393                                             nulo
# 401           HILUX, PRATA, 2011/2012, PLACA OCL5879
# 404                                             nulo
# 406                                             nulo
# 412                                             nulo
# 416                                             nulo
# 419                  POP100 PRETA, 12/12, OIH2476-CE
# 438                                             nulo
# 441                                             nulo
# 442                                            GOL 1
# 460                                             nulo
# 461                                             nulo
# 481                                             nulo
# 483                                             nulo
# 497                                             nulo
# 505                            BROS ES , 2012, PRETA
# 530     GOL SPECIAL, BRANCO, 2000, PLACA: HWE7217-CE
#
#                                VÍTIMA:   ...    MATERIAL APREENDIDO:  \
# 20                                nulo   ...                    nulo
# 25                     FRANCISCA K M F   ...                    nulo
# 30                                nulo   ...                    nulo
# 34                                nulo   ...                    nulo
# 39                              JOSÉ A   ...                    nulo
# 45                                nulo   ...                    nulo
# 46                                nulo   ...                    nulo
# 50                                nulo   ...                    nulo
# 51                                nulo   ...                    nulo
# 60                           JAILTON L   ...                    nulo
# 80                                nulo   ...                    nulo
# 84                                nulo   ...                    nulo
# 106                               nulo   ...                    nulo
# 110                               nulo   ...                    nulo
# 131                               nulo   ...                    nulo
# 142                               nulo   ...                    nulo
# 152                               nulo   ...                    nulo
# 156  SEXO MASCULINO, SEM IDENTIFICAÇÃO   ...                    nulo
# 168                             LUIZ B   ...                    nulo
# 175                               nulo   ...                    nulo
# 176                               nulo   ...                    nulo
# 194                               nulo   ...                    nulo
# 202                               nulo   ...                    nulo
# 229                               nulo   ...                    nulo
# 233                               nulo   ...                    nulo
# 234                               nulo   ...                    nulo
# 241                               nulo   ...                    nulo
# 246                               nulo   ...                 MACONHA
# 250                               nulo   ...                    nulo
# 270                         FABRÍCIO G   ...                    nulo
# ..                                 ...   ...                     ...
# 301                               nulo   ...                    nulo
# 310                            EDSON S   ...                    nulo
# 312   SEXO FEMININO, SEM IDENTIFICAÇÃO   ...                    nulo
# 314                          BUBOCAR B   ...                    nulo
# 316                               nulo   ...                    nulo
# 334                           LUCAS\nL   ...                    nulo
# 345                               nulo   ...                    nulo
# 363                               nulo   ...                    nulo
# 365                               nulo   ...                    nulo
# 376                               nulo   ...                    nulo
# 385                               nulo   ...                    nulo
# 388                               nulo   ...                    nulo
# 390                         JONATHAN S   ...                    nulo
# 393                     MENOR DE IDADE   ...                    nulo
# 401                               nulo   ...                    nulo
# 404                               nulo   ...                    nulo
# 406                               nulo   ...                    nulo
# 412                         ELINARDO S   ...                    nulo
# 416                               nulo   ...                    nulo
# 419                               nulo   ...                    nulo
# 438                        FRANCISCO A   ...                    nulo
# 441                               nulo   ...                    nulo
# 442                            MARCO A   ...                    nulo
# 460                          JAILSON T   ...                    nulo
# 461                               nulo   ...                    nulo
# 481                               nulo   ...                    nulo
# 483                               nulo   ...                    nulo
# 497                               nulo   ...    SIMULACRO DE PISTOLA
# 505                               nulo   ...                    nulo
# 530                               nulo   ...                    nulo
#
#          PLACA: VÍTIMAS LESIONADAS:  \
# 20         nulo                nulo
# 25         nulo                nulo
# 30         nulo                nulo
# 34         nulo                nulo
# 39         nulo                nulo
# 45         nulo                nulo
# 46         nulo                nulo
# 50         nulo                nulo
# 51         nulo                nulo
# 60         nulo                nulo
# 80         nulo                nulo
# 84         nulo                nulo
# 106        nulo                nulo
# 110        nulo                nulo
# 131  OCD7977-CE                nulo
# 142        nulo                nulo
# 152        nulo                nulo
# 156        nulo                nulo
# 168        nulo                nulo
# 175        nulo                nulo
# 176        nulo                nulo
# 194        nulo                nulo
# 202        nulo                nulo
# 229        nulo                nulo
# 233        nulo                nulo
# 234        nulo                nulo
# 241        nulo                nulo
# 246        nulo                nulo
# 250  PNM4326-CE                nulo
# 270        nulo                nulo
# ..          ...                 ...
# 301        nulo                nulo
# 310        nulo                nulo
# 312        nulo                nulo
# 314        nulo                nulo
# 316        nulo                nulo
# 334        nulo                nulo
# 345        nulo                nulo
# 363        nulo                nulo
# 365        nulo                nulo
# 376        nulo                nulo
# 385        nulo                nulo
# 388        nulo                nulo
# 390        nulo                nulo
# 393        nulo                nulo
# 401        nulo                nulo
# 404        nulo                nulo
# 406        nulo                nulo
# 412        nulo                nulo
# 416        nulo                nulo
# 419        nulo                nulo
# 438        nulo                nulo
# 441        nulo                nulo
# 442        nulo                nulo
# 460        nulo                nulo
# 461        nulo                nulo
# 481        nulo                nulo
# 483        nulo                nulo
# 497        nulo                nulo
# 505        nulo                nulo
# 530  HWE7217-CE                nulo
#
#                                             SUSPEITOS: HORA MINUTO      DATA  \
# 20                                                nulo   21     29  02/01/17
# 25   1oJOÃO CARLOS DOS SANTOS NOGUEIRA,24ANOS; 2oPA...   11     39  02/01/17
# 30                                                nulo   06     55  02/01/17
# 34                                                nulo   14     02  02/01/17
# 39                         NADA FOI INFORMADO NO LOCAL   20     04  03/01/17
# 45                                                nulo   12     55  03/01/17
# 46                                                nulo   15     27  03/01/17
# 50                                                nulo   13     27  03/01/17
# 51                                                nulo   14     15  03/01/17
# 60                                                nulo   08     45  04/01/17
# 106 -3.752435 -38.577180       4
# 110 -3.748972 -38.582790       4
# 131 -3.730041 -38.592455       4
# 142 -3.764873 -38.589081       4
# 152 -3.749739 -38.586151       4
# 156 -3.756597 -38.597994       4
# 168 -3.762672 -38.586020       4
# 175 -3.754801 -38.595137       4
# 176 -3.762208 -38.584548       4
# 194 -3.757612 -38.583595       4
# 202 -3.753588 -38.577174       4
# 229 -3.755699 -38.595302       4
# 233 -3.756976 -38.589479       4
# 234 -3.733898 -38.582361       4
# 241 -3.756198 -38.593404       4
# 246 -3.737844 -38.590363       4
# 250 -3.749041 -38.586496       4
# 270 -3.771384 -38.589909       4
# ..        ...        ...     ...
# 301 -3.744054 -38.589886       4
# 310 -3.724882 -38.590050       4
# 312 -3.754282 -38.602741       4
# 314 -3.739005 -38.585682       4
# 316 -3.747356 -38.592495       4
# 334 -3.765328 -38.585807       4
# 345 -3.752555 -38.593050       4
# 363 -3.739005 -38.585682       4
# 365 -3.757652 -38.581166       4
# 376 -3.730041 -38.592455       4
# 385 -3.752435 -38.577180       4
# 388 -3.764942 -38.580596       4
# 390 -3.764873 -38.589081       4
# 393 -3.754158 -38.595696       4
# 401 -3.744029 -38.591001       4
# 404 -3.729950 -38.591707       4
# 406 -3.762832 -38.581084       4
# 412 -3.749693 -38.594182       4
# 416 -3.758020 -38.595069       4
# 419 -3.736503 -38.584544       4
# 438 -3.759586 -38.584626       4
# 441 -3.754730 -38.579140       4
# 442 -3.762959 -38.575955       4
# 460 -3.766564 -38.588308       4
# 461 -3.754738 -38.576596       4
# 481 -3.752555 -38.593050       4
# 483 -3.749527 -38.586815       4
# 497 -3.757652 -38.581166       4
# 505 -3.750626 -38.579695       4
# 530 -3.740469 -38.589702       4
#
# [63 rows x 23 columns]

# %% [markdown]
# ### Uma análise sobre as 5 ocorrências mais comuns

# %%
crime_types = regiao_4_detalhe[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = regiao_4_detalhe[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5 = all_crime_types.head(5)

# %%
crimes_top_5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes na região 4')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 horários com mais ocorrências em janeiro

# %%
horas_mes = df_janeiro.HORA.value_counts()
horas_mes_top10 = horas_mes.head(10)

# %%
horas_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Crimes por hora (Jan 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 5 horários com mais ocorrências na região 4 (região com mais ocorrências em janeiro)

# %%
crime_hours = regiao_4_detalhe[['HORA']]
crime_hours_total = crime_hours.groupby('HORA').size()
crime_hours_counts = regiao_4_detalhe[['HORA']].groupby('HORA').sum()
crime_hours_counts['TOTAL'] = crime_hours_total
all_hours_types = crime_hours_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_hours_types.head(5)
# Out:
#       TOTAL
# HORA
# 11        8
# 17        7
# 07        5
# 08        5
# 19        5

# %%
all_hours_types_top5 = all_hours_types.head(5)
all_hours_types_top5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes por hora na região 4')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 bairros com mais ocorrências em janeiro

# %%
crimes_mes = df_janeiro.BAIRRO.value_counts()
crimes_mes_top10 = crimes_mes.head(10)

# %%
crimes_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Top 10 Bairros com mais crimes (Jan 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### O Bairro com o maior número de ocorrências em janeiro foi o Barra do Ceará

# %% [markdown]
# ### Vamos agora ver de forma mais detalhadas quais foram estes crimes

# %%
barra_do_ceara = df_janeiro[df_janeiro['BAIRRO'] == 'BARRA DO CEARA']
crime_types = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes na Barra do Ceará')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Os 5 bairros mais comuns na região 4

# %%
crime_types_bairro = regiao_4_detalhe[['BAIRRO']]
crime_type_total_bairro = crime_types_bairro.groupby('BAIRRO').size()
crime_type_counts_bairro = regiao_4_detalhe[['BAIRRO']].groupby('BAIRRO').sum()
crime_type_counts_bairro['TOTAL'] = crime_type_total_bairro
all_crime_types_bairro = crime_type_counts_bairro.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5_bairro = all_crime_types_bairro.head(5)
crimes_top_5_bairro.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 bairros na região 4')
plt.xlabel('Quantidade')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Análise sobre o bairo Henrique Jorge

# %%
henrique_jorge = df_janeiro[df_janeiro['BAIRRO'] == 'HENRIQUE JORGE']
crime_types = henrique_jorge[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = henrique_jorge[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes no Henrique Jorge')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
