# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df_abril = pandas.read_csv("./data/Cluster-Crime-Abril.csv")

# %%
crime_tipos = df_abril[['NATUREZA DA OCORRÊNCIA']]
crime_tipo_total = crime_tipos.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_tipo_counts = df_abril[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_tipo_counts['TOTAL'] = crime_tipo_total
all_crime_tipos = crime_tipo_counts.sort_values(by='TOTAL', ascending=False)

# %% [markdown]
# ### Filtro dos 10 crimes com mais ocorrências em abril

# %%
all_crime_tipos.head(10)
# Out:
#                                              TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                             190
# MORTE A BALA                                    79
# PORTE ILEGAL DE ARMA                            34
# TRAFICO DE ENTORPECENTES                        24
# ROUBO A PESSOA                                  17
# TRAFICO DE ENTORPECENTES (ATO INFRACIONAL)       8
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)           7
# TRAFICO DE ENTORPECENTE                          5
# VEICULO LOCALIZADO  (ATO INFRACIONAL)            5
# TRAFICO DE ENTORPECENTES  (ATO INFRACIONAL)      4

# %%
all_crime_tipos_top10 = all_crime_tipos.head(10)
all_crime_tipos_top10.plot(kind='barh', figsize=(12,6), color='#3f3fff')
plt.title('Top 10 crimes por tipo (Abr 2017)')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Todas as ocorrências criminais de abril

# %%
all_crime_tipos
# Out:
#                                                     TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                                    190
# MORTE A BALA                                           79
# PORTE ILEGAL DE ARMA                                   34
# TRAFICO DE ENTORPECENTES                               24
# ROUBO A PESSOA                                         17
# TRAFICO DE ENTORPECENTES (ATO INFRACIONAL)              8
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)                  7
# TRAFICO DE ENTORPECENTE                                 5
# VEICULO LOCALIZADO  (ATO INFRACIONAL)                   5
# TRAFICO DE ENTORPECENTES  (ATO INFRACIONAL)             4
# CUMPRIMENTO DE MANDADO JUDICIAL                         4
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)                 3
# EMBRIAGUEZ AO VOLANTE                                   3
# ROUBO A PESSOA  (ATO INFRACIONAL / FLAGRANTE)           3
# TRAFICO DE ENTORPECENTE (ATO INFRACIONAL)               3
# MORTE A FACA                                            3
# ROUBO DE VEICULO                                        3
# INCENDIO EM VEICULO SEM VITIMA                          3
# MORTES A BALA                                           3
# MORTE A OUTROS                                          2
# PESSOA EM SITUACAO SUSPEITA                             2
# MORTE A BALA SEGUIDA DE LESAO CORPORAL A BALA           2
# PORTE ILEGAL DE ARMA (BOC)                              2
# PORTE ILEGAL DE ARMA  (FLAGRANTE / ATO INFRACIO...      2
# LESAO CORPORAL A FACA                                   2
# APREENSAO DE ARMA                                       2
# ROUBO DE VEICULO (ATO INFRACIONAL / FLAGRANTE)          2
# ROUBO A PESSOA / PORTE ILEGAL DE ARMA                   2
# ABANDONO DE MATERIAL OU BENS MOVEIS                     2
# LESAO CORPORAL                                          2
# ...                                                   ...
# APREENSAO DE ARMA DE FOGO                               1
# MAUS TRATOS À CRIANCA, ADOLESCENTE OU IDOSO             1
# MORTE  A BALA                                           1
# PORTE ILEGAL DE ARMAS -  (FLAGRANTE / AUTO DE A...      1
# PORTE ILEGAL DE ARMA  VEICULO LOCALIZADO                1
# PORTE ILEGAL DE ARMAS  (FLAGRANTE / ATO INFRACI...      1
# PORTE ILEGAL DE ARMAS  (ATO INFRACIONAL / FLAGR...      1
# PORTE ILEGAL DE ARMAS                                   1
# PORTE ILEGAL DE ARMA TRAFICO  MACONHA                   1
# PORTE ILEGAL DE ARMA ROUBO DE VEICULO                   1
# PORTE ILEGAL DE ARMA /TRAFICO DE ENTORPECENTES          1
# PORTE ILEGAL DE ARMA / VEICULO APREENDIDO               1
# PORTE ILEGAL DE ARMA / TRAFICO DE ANTORPECENTES...      1
# PORTE ILEGAL DE ARMA / CUMPRIMENTO DE MANDADO           1
# PORTE ILEGAL DE ARMA -                                  1
# PORTE ILEGAL DE ARMA (FLAGRANTE /ATO INFRACIONAL)       1
# PORTE ILEGAL DE ARMA  (ARMAS APREENDIDAS / FLAG...      1
# MORTE A BALA  LESAO CORPORAL A BALA                     1
# PORTE ILEGAL DE ARMA  ( FLAGRANTE )                     1
# PORTE ILEGAL DE ARMA  ( ATO INFRACIONAL )               1
# PORTE ILEGAL DE ARMA   (ATO INFRACIONAL)                1
# PORTE ILEGAL DE ARMA   (ATO INFRACIONAL  FLAGRA...      1
# PESSOAS EM SITUACAO SUSPEITA (AUTO DE APREENSAO...      1
# PESSOA EM SITUACAO SUSPEITA (AUTO DE APREENSAO)         1
# MORTES A BALA SEGUIDA DE LESAO CORPORAL A BALA          1
# MORTE A BALA LESÕES CORPORAL A BALA                     1
# MORTE A BALA LESAO CORPORAL A BALA                      1
# MORTE A BALA APREENSAO DE ARMA                          1
# MORTE A BALA  LESÕES CORPORAIS A BALA                   1
# VIOLACAO A DOMICILIO / CRIME DE DANO                    1
#
# [133 rows x 1 columns]

# %%
group_df_abril = df_abril.groupby('CLUSTER')
crimes = group_df_abril['NATUREZA DA OCORRÊNCIA'].count()

# %%
crimes.plot(kind='barh', figsize=(10,7), color='#3f3fff')
plt.title('Número de crimes por região (Abr 2017)')
plt.xlabel('Número')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### As 5 regiões com mais ocorrências

# %%
regioes = df_abril.groupby('CLUSTER').count()
grupo_de_regioes = regioes.sort_values('NATUREZA DA OCORRÊNCIA', ascending=False)

# %%
grupo_de_regioes['TOTAL'] = grupo_de_regioes.ID
top_5_regioes_qtd = grupo_de_regioes.TOTAL.head(6)

# %%
top_5_regioes_qtd.plot(kind='barh', figsize=(10,4), color='#3f3fff')
plt.title('Top 5 regiões com mais crimes')
plt.xlabel('Número de crimes')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Acima podemos ver que a região 1 teve o maior número de ocorrências criminais

# %% [markdown]
# ### Podemos agora ver quais são essas ocorrências de forma mais detalhada

# %%
regiao_1_detalhe = df_abril[df_abril['CLUSTER'] == 1]
regiao_1_detalhe
# Out:
#       ID  FONTE FLAGRANTE                             NATUREZA DA OCORRÊNCIA  \
# 1      2  CIOPS       SIM                 HOMICIDIO A BALA / ARMA APREENDIDA
# 31    32  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 35    36  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 47    48  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 48    49  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 104  105  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 111  112  CIOPS       SIM                           TRAFICO DE ENTORPECENTES
# 113  114  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 114  115  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 132  133  CIOPS       NÃO                PORTE ILEGAL DE ARMA  ( FLAGRANTE )
# 140  141  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 161  162  CIOPS       NÃO                                       MORTE A BALA
# 180  181  CIOPS       NÃO                 MORTE A BALA LESAO CORPORAL A BALA
# 184  185  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 185  186  CIOPS       NÃO  APREENSAO DE ARMA SEGUIDO DE LOCALIZACAO DE VE...
# 193  194  CIOPS       SIM                                   ROUBO A COLETIVO
# 214  215  CIOPS       NÃO          TRAFICO DE ENTORPECENTE (ATO INFRACIONAL)
# 223  224  CIOPS       NÃO            PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)
# 244  245  CIOPS       NÃO                                       MORTE A BALA
# 272  273  CIOPS       NÃO     ROUBO DE VEICULO (ATO INFRACIONAL / FLAGRANTE)
# 277  278  CIOPS       SIM           PORTE ILEGAL DE ARMA  VEICULO LOCALIZADO
# 281  282  CIOPS       SIM                                     ROUBO A PESSOA
# 285  286  CIOPS       NÃO                                       MORTE A BALA
# 293  294  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 297  298  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 338  339  CIOPS       NÃO  VEICULO LOCALIZADO  (ATO INFRACIONAL / FLAGRANTE)
# 346  347  CIOPS       NÃO                     INCENDIO EM VEICULO SEM VITIMA
# 374  375  CIOPS       NÃO                                       MORTE A BALA
# 381  382  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 416  417  CIOPS       NÃO                                       MORTE A BALA
# 424  425  CIOPS       NÃO                                APREENSAO DE DROGAS
# 425  426  CIOPS       SIM                        PESSOA EM SITUACAO SUSPEITA
# 427  428  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 432  433  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 434  435  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 449  450  CIOPS       NÃO  TENTATIVA DE ROUBO A PESSOA (AUTO DE APREENSAO...
# 453  454  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 454  455  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 472  473  CIOPS       NÃO                                       MORTE A BALA
# 474  475  CIOPS       NÃO                                       MORTE A FACA
# 488  489  CIOPS       NÃO        TRAFICO DE ENTORPECENTES  (ATO INFRACIONAL)
# 504  505  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 511  512  CIOPS       NÃO                                       MORTE A BALA
# 513  514  CIOPS       NÃO                                       MORTE A BALA
# 522  523  CIOPS       NÃO      ROUBO A PESSOA  (ATO INFRACIONAL / FLAGRANTE)
#
#                                HISTÓRICO DA OCORRÊNCIA  \
# 1    LOCAL: RUA VIOLETA, ÁLVARO WEYNE.VÍTIMA: DARLI...
# 31   LOCAL: RUA ENCANTO DA BARRA, BARRA DO CEARÁ.  ...
# 35   LOCAL: RUA CAUBI, BARRA DO CEARÁ.  VEÍCULO: CG...
# 47   LOCAL: RUA FREI TEOBALDO, CARLITO PAMPLONA.  V...
# 48   LOCAL: RUA HENRIQUE ELLERY, CARLITO PAMPLONA. ...
# 104  LOCAL: RUA GRAÇA ARANHA, BARRA DO CEARÁ.  VEÍC...
# 111  LOCAL:RUAEDUDAGAITA,BARRADOCEARÁ.MATERIALAPREE...
# 113  LOCAL: RUA COELHO NETO, JARDIM IRACEMA.  VEÍCU...
# 114  LOCAL: AV. ABOLICIONISTA, BARRA DO CEARÁ.  VEÍ...
# 132  LOCAL: RUA DOS LAGOS, ÁLVARO WEYNE.  ARMA APRE...
# 140  LOCAL: RUA SÃO BERNARDO, 1074, BARRA DO CEARÁ....
# 161  LOCAL: RUA SAUDARIA, BARRA DO CEARÁ.  VÍTIMA: ...
# 180  LOCAL: RUA SÃO PEDRO, BARRA DO CEARÁ.  VÍTIMA ...
# 184  LOCAL: RUA DOS HOLANDESES, BARRA DO CEARÁ. SUS...
# 185  LOCAL: AV. DOUTOR THEBERGE, ÁLVARO WEYNE.ARMA ...
# 193  LOCAL: RUA GENERAL OLÍMPIO, QUINTINO CUNHA.QUA...
# 214  LOCAL:AV. FRANCISCO SÁ,ALVARO WEYNE.SUSPEITOS:...
# 223  LOCAL:RUAEXPEDITOXAVIER,FLORESTA.SUSPEITO:MENO...
# 244  LOCAL: TV. DOIS, BARRA DO CEARÁ. VÍTIMA: SEXO ...
# 272  LOCAL: RUA SÃO ROQUE, ÁLVARO WEYNE.VEÍCULO: SI...
# 277  LOCAL: RUATEODOMIRO DE CASTRO, ÁLVARO WEINE.AR...
# 281  LOCAL: RUA IRAPUAN, BARRA DO CEARÁ.VÍTIMA: CLE...
# 285  LOCAL: RUA BAMBUI, BARRA DO CEARÁ.  VÍTIMA: FR...
# 293  LOCAL: AV. FRANCISCO SÁ, CARLITO PAMPLONA.  VE...
# 297  LOCAL: RUA CINCO, SÃO GERARDO.  VEÍCULO: CG 12...
# 338  LOCAL: AV. PRESIDENTE CASTELO BRANCO, BARRA DO...
# 346  LOCAL: RUA LUIS GUIMARÃES, ÁLVARO WEYNE.  VEÍC...
# 374  LOCAL: RUA CÉSAR CORREIA, BARRA DO CEARÁ.  VÍT...
# 381  LOCAL: RUA LARGA, BARRA DO CEARÁ.  VEÍCULO: TV...
# 416  LOCAL: RUA DO CÉU, PIRAMBU.  VÍTIMA: RODRIGO P...
# 424  LOCAL:RUASANTOANTÔNIO,BARRADOCEARÁ.DROGASAPREE...
# 425  LOCAL:AV.FRANCISCOSÁ,ÁLVAROWEYNE.SUSPEITO:ANTÔ...
# 427  LOCAL: RUA TENENTE LISBOA, ELLERY.  VEÍCULO: F...
# 432  LOCAL: TV. JACKSON DO PANDEIRO, BARRA DO CEARÁ...
# 434  LOCAL: RUA HIDELBRANDO DE MELO, BARRA DO CEARÁ...
# 449  LOCAL:AV.FRANCISCOSÁ,CARLITOPAMPLONA.SUSPEITOS...
# 453  LOCAL: AV. FRANCISCO SA, ALVARO WEYNE.  VEÍCUL...
# 454  LOCAL: RUA JOAQUIM PINTO, ÁLVARO WEYNE.  VEÍCU...
# 472  LOCAL: RUA TEODOMIRO DE CASTRO, ALVARO WEYNE. ...
# 474  LOCAL: RUA ARAQUEM, BARRA DO CEARA.  VÍTIMA: S...
# 488  LOCAL: RUA CESAR CORREIA, ALVARO WEYNE.SUSPEIT...
# 504  LOCAL: RUA CINCO, BARRA DO CEARA.  VEÍCULO: CE...
# 511  LOCAL: RUA SÃ PEDRO, BARRA DO CEARÁ.  VÍTIMA: ...
# 513  LOCAL: AV FRANCISCO SA, BARRA DO CEARA.  VÍTIM...
# 522  LOCAL: AV. FRANCISCO SÁ, ALVARO WEYNE.VÍTIMA: ...
#
#                                             LOCAL:                BAIRRO  \
# 1                        RUA VIOLETA, ALVARO WEYNE          ALVARO WEYNE
# 31            RUA ENCANTO DA BARRA, BARRA DO CEARA        BARRA DO CEARA
# 35                       RUA CAUBI, BARRA DO CEARA        BARRA DO CEARA
# 47             RUA FREI TEOBALDO, CARLITO PAMPLONA      CARLITO PAMPLONA
# 48           RUA HENRIQUE ELLERY, CARLITO PAMPLONA      CARLITO PAMPLONA
# 104               RUA GRACA ARANHA, BARRA DO CEARA        BARRA DO CEARA
# 111                     RUAEDUDAGAITA,BARRADOCEARA          BARRADOCEARA
# 113                RUA COELHO NETO, JARDIM IRACEMA        JARDIM IRACEMA
# 114              AV. ABOLICIONISTA, BARRA DO CEARA        BARRA DO CEARA
# 132                    RUA DOS LAGOS, ALVARO WEYNE          ALVARO WEYNE
# 140         RUA SAO BERNARDO, 1074, BARRA DO CEARA  1074, BARRA DO CEARA
# 161                   RUA SAUDARIA, BARRA DO CEARA        BARRA DO CEARA
# 180                  RUA SAO PEDRO, BARRA DO CEARA        BARRA DO CEARA
# 184             RUA DOS HOLANDESES, BARRA DO CEARA        BARRA DO CEARA
# 185              AV. DOUTOR THEBERGE, ALVARO WEYNE          ALVARO WEYNE
# 193            RUA GENERAL OLIMPIO, QUINTINO CUNHA        QUINTINO CUNHA
# 214                  AV. FRANCISCO SA,ALVARO WEYNE          ALVARO WEYNE
# 223                     RUAEXPEDITOXAVIER,FLORESTA              FLORESTA
# 244                        TV DOIS, BARRA DO CEARA        BARRA DO CEARA
# 272                    RUA SAO ROQUE, ALVARO WEYNE          ALVARO WEYNE
# 277           RUATEODOMIRO DE CASTRO, ALVARO WEINE          ALVARO WEINE
# 281                    RUA IRAPUAN, BARRA DO CEARA        BARRA DO CEARA
# 285                     RUA BAMBUI, BARRA DO CEARA        BARRA DO CEARA
# 293             AV. FRANCISCO SA, CARLITO PAMPLONA      CARLITO PAMPLONA
# 297                         RUA CINCO, SAO GERARDO           SAO GERARDO
# 338  AV. PRESIDENTE CASTELO BRANCO, BARRA DO CEARA        BARRA DO CEARA
# 346               RUA LUIS GUIMARAES, ALVARO WEYNE          ALVARO WEYNE
# 374              RUA CESAR CORREIA, BARRA DO CEARA        BARRA DO CEARA
# 381                      RUA LARGA, BARRA DO CEARA        BARRA DO CEARA
# 416                            RUA DO CEU, PIRAMBU               PIRAMBU
# 424                   RUASANTOANTONIO,BARRADOCEARA          BARRADOCEARA
# 425                     AV.FRANCISCOSA,ALVAROWEYNE           ALVAROWEYNE
# 427                     RUA TENENTE LISBOA, ELLERY                ELLERY
# 432         TV JACKSON DO PANDEIRO, BARRA DO CEARA        BARRA DO CEARA
# 434        RUA HIDELBRANDO DE MELO, BARRA DO CEARA        BARRA DO CEARA
# 449                 AV.FRANCISCOSA,CARLITOPAMPLONA       CARLITOPAMPLONA
# 453                 AV. FRANCISCO SA, ALVARO WEYNE          ALVARO WEYNE
# 454                RUA JOAQUIM PINTO, ALVARO WEYNE          ALVARO WEYNE
# 472          RUA TEODOMIRO DE CASTRO, ALVARO WEYNE          ALVARO WEYNE
# 474                    RUA ARAQUEM, BARRA DO CEARA        BARRA DO CEARA
# 488                RUA CESAR CORREIA, ALVARO WEYNE          ALVARO WEYNE
# 504                      RUA CINCO, BARRA DO CEARA        BARRA DO CEARA
# 511                   RUA SA PEDRO, BARRA DO CEARA        BARRA DO CEARA
# 513                AV FRANCISCO SA, BARRA DO CEARA        BARRA DO CEARA
# 522                 AV. FRANCISCO SA, ALVARO WEYNE          ALVARO WEYNE
#
#                                     SUSPEITO:  \
# 1                                        nulo
# 31                                       nulo
# 35                                       nulo
# 47                                       nulo
# 48                                       nulo
# 104                                      nulo
# 111                  DIEGOFORTEDESOUSA,19ANOS
# 113                                      nulo
# 114                                      nulo
# 132           LEMOEL DA SILVA SANTOS, 2\nANOS
# 140                                      nulo
# 161                                      nulo
# 180                          NÃO IDENTIFICADO
# 184              EMANUEL DIAS DUARTE, 23 ANOS
# 185                                      nulo
# 193                                      nulo
# 214                                      nulo
# 223                              MENORDEIDADE
# 244                          NÃO IDENTIFICADO
# 272                                      nulo
# 277          PAULOMARCELOARAÚJODESOUSA,22ANOS
# 281  JOSÉ CARLOS OLIVEIRA DOS SANTOS, 19 ANOS
# 285                          NÃO IDENTIFICADO
# 293                                      nulo
# 297                                      nulo
# 338                                      nulo
# 346                                      nulo
# 374                                      nulo
# 381                                      nulo
# 416                                      nulo
# 424                                      nulo
# 425           ANTÔNIOROBSONSALESLOIOLA,29ANOS
# 427                                      nulo
# 432                                      nulo
# 434                                      nulo
# 449                                      nulo
# 453                                      nulo
# 454                                      nulo
# 472                          NÃO IDENTIFICADO
# 474                          NÃO IDENTIFICADO
# 488                            MENOR DE IDADE
# 504                                      nulo
# 511                                      nulo
# 513                                      nulo
# 522                                      nulo
#
#                                             VEÍCULO:  \
# 1                                               nulo
# 31         CG 125 FAN ES, VERMELHA, 2012, OIM2333-CE
# 35       CG 160 TITAN EX, VERMELHA, 2016, PNB2860-CE
# 47                   CB 500F, BRANCA, 2014,  PMF8447
# 48                                          PRISMA 1
# 104                  FAN ESDI,14,VERMELHA,ORV9640-CE
# 111                                             nulo
# 113         FAN ESDI, 2016, PRETA, PLACA: PMP5214-CE
# 114          BIZ 125 ES, VERMELHA, PLACA: OCD4931-CE
# 132                                             nulo
# 140        NXR150 BROS KS, PRETA, 2009/2009, NRD1130
# 161                                             nulo
# 180                                             nulo
# 184                                             nulo
# 185                                             nulo
# 193                                             nulo
# 214                                             nulo
# 223                                             nulo
# 244                                             nulo
# 272                                       SIENA EL 1
# 277      CG 160 START, VERMELHA,2016/2016,PNM5626-CE
# 281                                             nulo
# 285                                             nulo
# 293               HB20, PRETA, 2013/2013, PFU0805-CE
# 297           CG 125 FAN KS, 2011, PRETA, OCH5881-CE
# 338                   FAN ESI, PRETA, 13, ORP0394-CE
# 346                                           ÔNIBUS
# 374                                             nulo
# 381  TVS APACHE RTR 150, VERMELHA, 10/11, NRD2736-CE
# 416                                             nulo
# 424                                             nulo
# 425                                             nulo
# 427                     FAN KS, PRETA, 10/10, NUM762
# 432              SIENA EL FLEX, 12, BEGE, OCE1829-CE
# 434               YBR 125K, 07, VERMELHA, HYH2682-CE
# 449                                             nulo
# 453   ETIOS SD XS, VERMELHA, 2015, PLACA: PMI2496-CE
# 454       FAN ESD, VERMELHA,14/15, PLACA: ORZ2140-CE
# 472                                             nulo
# 474                                             nulo
# 488                                             nulo
# 504                                          CELTA 1
# 511                                             nulo
# 513                                             nulo
# 522                                             nulo
#
#                                VÍTIMA:   ...   MATERIAL APREENDIDO:  \
# 1                            DARLIEL N   ...                   nulo
# 31                                nulo   ...                   nulo
# 35                                nulo   ...                   nulo
# 47                                nulo   ...                   nulo
# 48                                nulo   ...                   nulo
# 104                               nulo   ...                   nulo
# 111                               nulo   ...                   nulo
# 113                               nulo   ...                   nulo
# 114                               nulo   ...                   nulo
# 132                               nulo   ...                   nulo
# 140                               nulo   ...                   nulo
# 161                           FILIPE N   ...                   nulo
# 180                               nulo   ...                   nulo
# 184                               nulo   ...                   nulo
# 185                               nulo   ...                   nulo
# 193                               nulo   ...              SIMULACRO
# 214                               nulo   ...                   nulo
# 223                               nulo   ...                   nulo
# 244  SEXO MASCULINO, SEM IDENTIFICAÇÃO   ...                   nulo
# 272                          LIDIANE A   ...                   nulo
# 277                               nulo   ...                   nulo
# 281                         CLETEMIR M   ...                   nulo
# 285                        FRANCISCO N   ...                   nulo
# 293                               nulo   ...                   nulo
# 297                               nulo   ...                   nulo
# 338                               nulo   ...                   nulo
# 346                               nulo   ...                   nulo
# 374                          ROGÉRIO C   ...                   nulo
# 381                               nulo   ...                   nulo
# 416                          RODRIGO P   ...                   nulo
# 424                               nulo   ...                   nulo
# 425                               nulo   ...                   nulo
# 427                               nulo   ...                   nulo
# 432                               nulo   ...                   nulo
# 434                               nulo   ...                   nulo
# 449                               nulo   ...                   nulo
# 453                               nulo   ...                   nulo
# 454                               nulo   ...                   nulo
# 472                        SEBASTIÃO S   ...                   nulo
# 474  SEXO MASCULINO, SEM IDENTIFICAÇÃO   ...                   nulo
# 488                               nulo   ...                COCAÍNA
# 504                               nulo   ...                   nulo
# 511                     MENOR DE IDADE   ...                   nulo
# 513                          GILMAR RS   ...                   nulo
# 522                        FRANCISCO L   ...                   nulo
#
#          PLACA: VÍTIMAS LESIONADAS:  \
# 1          nulo                nulo
# 31         nulo                nulo
# 35         nulo                nulo
# 47         nulo                nulo
# 48         nulo                nulo
# 104        nulo                nulo
# 111        nulo                nulo
# 113  PMP5214-CE                nulo
# 114  OCD4931-CE                nulo
# 132        nulo                nulo
# 140        nulo                nulo
# 161        nulo                nulo
# 180        nulo                nulo
# 184        nulo                nulo
# 185        nulo                nulo
# 193        nulo                nulo
# 214        nulo                nulo
# 223        nulo                nulo
# 244        nulo                nulo
# 272  OSL1425-CE                nulo
# 277        nulo                nulo
# 281        nulo                nulo
# 285        nulo                nulo
# 293        nulo                nulo
# 297        nulo                nulo
# 338        nulo                nulo
# 346        nulo                nulo
# 374        nulo                nulo
# 381        nulo                nulo
# 416        nulo                nulo
# 424        nulo                nulo
# 425        nulo                nulo
# 427        nulo                nulo
# 432        nulo                nulo
# 434        nulo                nulo
# 449        nulo                nulo
# 453  PMI2496-CE                nulo
# 454  ORZ2140-CE                nulo
# 472        nulo                nulo
# 474        nulo                nulo
# 488        nulo                nulo
# 504        nulo                nulo
# 511        nulo                nulo
# 513        nulo                nulo
# 522        nulo                nulo
#
#                                             SUSPEITOS: HORA MINUTO      DATA  \
# 1                                                 nulo   19     15  01/04/17
# 31                                                nulo   10     36  02/04/17
# 35                                                nulo   17      7  02/04/17
# 47                                                nulo    9      9  03/04/17
# 48                                                nulo    9     11  03/04/17
# 104                                               nulo   20      9  05/04/17
# 111                                               nulo   22     53  06/04/17
# 113                                               nulo    7     51  06/04/17
# 114                                               nulo    8      8  06/04/17
# 132                                               nulo   18     41  07/04/17
# 140                                               nulo   17     35  07/04/17
# 161                                  NÃO IDENTIFICADOS    6     47  09/04/17
# 180                                               nulo    8     10  10/04/17
# 184                                               nulo   14     15  10/04/17
# 185                                               nulo   16     58  10/04/17
# 193           1o ANTÔNIO EDUARDO SILVA BARROS, 22 ANOS   22      6  10/04/17
# 214                              DOIS MENOSRES DEIDADE   18     41  13/04/17
# 223                                               nulo    9      4  14/04/17
# 244                                               nulo   13     37  15/04/17
# 272  1o - MENOR D\nIDADE, 2o - FRANCISCO JOSÉ RANIE...   10     50  16/04/17
# 277                                               nulo   12      6  17/04/17
# 281                                               nulo   21     10  17/04/17
# 285                                               nulo   19     13  18/04/17
# 293                                               nulo   10     14  18/04/17
# 297                                               nulo   15     56  18/04/17
# 338                                               nulo   10     43  20/04/17
# 346                                               nulo   10     56  20/04/17
# 374                      TRÊS HOMENS NÃO IDENTIFICADOS   12     49  22/04/17
# 381                                               nulo   13     13  22/04/17
# 416                                  NÃO IDENTIFICADOS   14     56  25/04/17
# 424                                               nulo   15     46  25/04/17
# 425                                               nulo   18     50  25/04/17
# 427                                               nulo    0     16  25/04/17
# 432                                               nulo   13     18  25/04/17
# 434                                               nulo   14     30  25/04/17
# 449                                     1°MENORDEIDADE   12     21  26/04/17
# 453                                               nulo    9      3  26/04/17
# 454                                               nulo    9     10  26/04/17
# 472                                               nulo   10     17  27/04/17
# 474                                               nulo   16     30  27/04/17
# 488                                               nulo   20     40  27/04/17
# 504                                               nulo    8     33  28/04/17
# 511                                  NÃO IDENTIFICADOS   16     53  29/04/17
# 513                                 NÃO INDENTIFICADOS   20     12  29/04/17
# 522                                1o – MENOR DE IDADE   17     13  29/04/17
#
#      LATITUDE  LONGITUDE CLUSTER
# 1   -3.712074 -38.563561       1
# 31  -3.700226 -38.577911       1
# 35  -3.704331 -38.578330       1
# 47  -3.715135 -38.559313       1
# 48  -3.720504 -38.561300       1
# 104 -3.708461 -38.573235       1
# 111 -3.701060 -38.579535       1
# 113 -3.715804 -38.576439       1
# 114 -3.697524 -38.580913       1
# 132 -3.724514 -38.576181       1
# 140 -3.711876 -38.579291       1
# 161 -3.701087 -38.583796       1
# 180 -3.695742 -38.582127       1
# 184 -3.699454 -38.579887       1
# 185 -3.715996 -38.565399       1
# 193 -3.717785 -38.559711       1
# 214 -3.713664 -38.568259       1
# 223 -3.722112 -38.572511       1
# 244 -3.710229 -38.582774       1
# 272 -3.717875 -38.571463       1
# 277 -3.718736 -38.572370       1
# 281 -3.704038 -38.584731       1
# 285 -3.705914 -38.582690       1
# 293 -3.716097 -38.561250       1
# 297 -3.710493 -38.582372       1
# 338 -3.703975 -38.579084       1
# 346 -3.721883 -38.570127       1
# 374 -3.708817 -38.572186       1
# 381 -3.699130 -38.585014       1
# 416 -3.707024 -38.565155       1
# 424 -3.696404 -38.582240       1
# 425 -3.713664 -38.568259       1
# 427 -3.721108 -38.566982       1
# 432 -3.698108 -38.582227       1
# 434 -3.710379 -38.588124       1
# 449 -3.716097 -38.561250       1
# 453 -3.713664 -38.568259       1
# 454 -3.716843 -38.567824       1
# 472 -3.718736 -38.572370       1
# 474 -3.706755 -38.578689       1
# 488 -3.711953 -38.573317       1
# 504 -3.710493 -38.582372       1
# 511 -3.695742 -38.582127       1
# 513 -3.714249 -38.566566       1
# 522 -3.713664 -38.568259       1
#
# [45 rows x 23 columns]

# %% [markdown]
# ### Uma análise sobre as 5 ocorrências mais comuns

# %%
crime_types = regiao_1_detalhe[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = regiao_1_detalhe[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5 = all_crime_types.head(5)
crimes_top_5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes na região 1')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 horários com mais ocorrências em abril

# %%
horas_mes = df_abril.HORA.value_counts()
horas_mes_top10 = horas_mes.head(10)

# %%
horas_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Crimes por hora (Abr 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 5 horários com mais ocorrências na região 1 (região com mais ocorrências em abril)

# %%
crime_hours = regiao_1_detalhe[['HORA']]
crime_hours_total = crime_hours.groupby('HORA').size()
crime_hours_counts = regiao_1_detalhe[['HORA']].groupby('HORA').sum()
crime_hours_counts['TOTAL'] = crime_hours_total
all_hours_types = crime_hours_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_hours_types.head(5)
# Out:
#       TOTAL
# HORA
# 10        6
# 9         5
# 14        3
# 17        3
# 20        3

# %%
all_hours_types_top5 = all_hours_types.head(5)
all_hours_types_top5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes por hora na região 1')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 bairros com mais ocorrências em abril

# %%
crimes_mes = df_abril.BAIRRO.value_counts()
crimes_mes_top10 = crimes_mes.head(10)

# %%
crimes_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Top 10 Bairros com mais crimes (Abr 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### O Bairro com o maior número de ocorrências em abril foi o Jangurussú

# %% [markdown]
# ### Vamos agora ver de forma mais detalhadas quais foram estes crimes

# %%
barra_do_ceara = df_abril[df_abril['BAIRRO'] == 'JANGURUSSU']
crime_types = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes no Jangurussú')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Os 5 bairros mais comuns na região 1

# %%
crime_types_bairro = regiao_1_detalhe[['BAIRRO']]
crime_type_total_bairro = crime_types_bairro.groupby('BAIRRO').size()
crime_type_counts_bairro = regiao_1_detalhe[['BAIRRO']].groupby('BAIRRO').sum()
crime_type_counts_bairro['TOTAL'] = crime_type_total_bairro
all_crime_types_bairro = crime_type_counts_bairro.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5_bairro = all_crime_types_bairro.head(5)
crimes_top_5_bairro.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 bairros na região 1')
plt.xlabel('Quantidade')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Análise sobre o bairro Barra do Ceará

# %%
barra_do_ceara = df_abril[df_abril['BAIRRO'] == 'BARRA DO CEARA']
crime_types = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = barra_do_ceara[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes na Barra do Ceará')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
