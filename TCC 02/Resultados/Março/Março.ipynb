# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df_marco = pandas.read_csv("./data/Cluster-Crime-Marco.csv")

# %%
crime_tipos = df_marco[['NATUREZA DA OCORRÊNCIA']]
crime_tipo_total = crime_tipos.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_tipo_counts = df_marco[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_tipo_counts['TOTAL'] = crime_tipo_total
all_crime_tipos = crime_tipo_counts.sort_values(by='TOTAL', ascending=False)

# %% [markdown]
# ### Filtro dos 10 crimes com mais ocorrências em março

# %%
all_crime_tipos.head(10)
# Out:
#                                          TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                         225
# MORTE A BALA                                75
# PORTE ILEGAL DE ARMA                        45
# TRAFICO DE ENTORPECENTES                    20
# ROUBO A PESSOA                              11
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)      10
# CUMPRIMENTO DE MANDADO JUDICIAL              9
# VEICULOS LOCALIZADOS                         9
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)      6
# VEICULO LOCALIZADO (ATO INFRACIONAL)         5

# %%
all_crime_tipos_top10 = all_crime_tipos.head(10)
all_crime_tipos_top10.plot(kind='barh', figsize=(12,6), color='#3f3fff')
plt.title('Top 10 crimes por tipo (Mar 2017)')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Todas as ocorrências criminais de março

# %%
all_crime_tipos
# Out:
#                                                     TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                                    225
# MORTE A BALA                                           75
# PORTE ILEGAL DE ARMA                                   45
# TRAFICO DE ENTORPECENTES                               20
# ROUBO A PESSOA                                         11
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)                 10
# CUMPRIMENTO DE MANDADO JUDICIAL                         9
# VEICULOS LOCALIZADOS                                    9
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)                 6
# VEICULO LOCALIZADO (ATO INFRACIONAL)                    5
# ROUBO DE VEICULO                                        5
# MORTES A BALA                                           5
# TRAFICO DE ENTORPECENTES (ATO INFRACIONAL)              4
# MORTE A OUTROS                                          4
# TRAFICO DE ENTORPECENTE                                 4
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL / FLAGRANTE)      4
# VEICULO LOCALIZADO  (ATO INFRACIONAL)                   3
# ABANDONO DE MATERIAL                                    3
# PORTE ILEGAL DE ARMA / TRAFICO DE ENTORPECENTE          3
# CAPTURA DE PRESO/FUGITIVO                               3
# MORTE A FACA                                            3
# APREENSAO DE ARMA                                       3
# MORTE  A BALA                                           2
# LESAO CORPORAL DOLOSA                                   2
# TRAFICO DE ENTORPECENTES ( FLAGRANTE )                  2
# EMBRIAGUEZ AO VOLANTE                                   2
# ABANDONO DE MATERIAL OU BENS MOVEIS                     2
# MORTE A BALA SEGUIDA DE LESAO CORPORAL A BALA           2
# APREENSAO DE ENTORPECENTES                              2
# ROUBO DE VEICULO (AUTO DE APREENSAO)                    2
# ...                                                   ...
# PORTE ILEGAL DE ARMA (FLAGRANTE / ATO INFRACIONAL)      1
# PORTE ILEGAL DE ARMA / ARMAS APREENDIDAS / ATO ...      1
# PORTE ILEGAL DE ARMA / TRAFICO DE ENTORPECENTES         1
# PORTE ILEGAL DE ARMA/TRAFICO DE ENTORPECENTES           1
# PORTE ILEGAL DE ARMA  (FLAGRANTE / AUTO DE APRE...      1
# PORTE ILEGAL DE ARMAS                                   1
# PORTE ILEGAL DE ARMAS  (ATO INFRACIONAL/ FLAGRA...      1
# PORTE ILEGAL DE ARMAVEICULO LOCALIZADO                  1
# RECEPTACAO  (ATO INFRACIONAL)                           1
# ROUBO  A ESTABELECIMENTO  ARMA APREENDIDA               1
# ROUBO  DE VEICULO (ARMA APREENDIDA/FLAGRANTE)           1
# PORTE ILEGAL DE ARMA  (FLAGRANTE/ATO INFRACIONAL)       1
# PORTE ILEGAL DE ARMA  (FLAGRANTE / ATO INFRACIO...      1
# MORTE A BALA ARMA APREENDIDA                            1
# PESSOA EM SITUACAO SUSPEITA                             1
# MORTE A BALA E LESAO CORPORAL A BALA                    1
# MORTE A BALA SEGUIDA LESAO CORPORAL A BALA              1
# MORTE A BALA SEGUIDO DE LESAO CORPORAL                  1
# MORTE A FACA (ATO INFRACIONAL)                          1
# MORTES A BALA  SEGUIDO DE LESAO COPORAL A BALA ...      1
# OUTROS CRIMES DE TRANSITO                               1
# PESSOA EM SITUACAO SUSPEITA (ATO INFRACIONAL)           1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL/FLAGRANTE)       1
# PORTE DE ARMA BRANCA (ATO INFRACIONAL)                  1
# PORTE ILEGAL DE ARMA   (FLAGRANTE / AUTO DE APR...      1
# PORTE ILEGAL DE ARMA  ( FLAGRANTE )                     1
# PORTE ILEGAL DE ARMA  (ATO INFRACIOANAL / FLAGR...      1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL / FLAGRA...      1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL/ FLAGRANTE)      1
# VIOLACAO A DOMICILIO  (T.C.O.)                          1
#
# [165 rows x 1 columns]

# %% [markdown]
# ## Quantidade de crimes por região

# %%
group_df_marco = df_marco.groupby('CLUSTER')
crimes = group_df_marco['NATUREZA DA OCORRÊNCIA'].count()

# %%
crimes.plot(kind='barh', figsize=(10,7), color='#3f3fff')
plt.title('Número de crimes por região (Mar 2017)')
plt.xlabel('Número')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### As 5 regiões com mais ocorrências

# %%
regioes = df_marco.groupby('CLUSTER').count()
grupo_de_regioes = regioes.sort_values('NATUREZA DA OCORRÊNCIA', ascending=False)

# %%
grupo_de_regioes['TOTAL'] = grupo_de_regioes.ID
top_5_regioes_qtd = grupo_de_regioes.TOTAL.head(6)

# %%
top_5_regioes_qtd.plot(kind='barh', figsize=(10,4), color='#3f3fff')
plt.title('Top 5 regiões com mais crimes')
plt.xlabel('Número de crimes')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Acima podemos ver que a região 4 teve o maior número de ocorrências criminais

# %% [markdown]
# ### Podemos agora ver quais são essas ocorrências de forma mais detalhada

# %%
regiao_4_detalhe = df_marco[df_marco['CLUSTER'] == 4]
regiao_4_detalhe
# Out:
#       ID  FONTE FLAGRANTE                             NATUREZA DA OCORRÊNCIA  \
# 15    16  CIOPS       NÃO                                       MORTE A BALA
# 17    18  CIOPS       SIM                              ROUBO ESTABELECIMENTO
# 26    27  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 32    33  CIOPS       NÃO                       MORTE A BALA ARMA APREENDIDA
# 53    54  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 55    56  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 73    74  CIOPS       SIM                                     ROUBO A PESSOA
# 76    77  CIOPS       SIM                            TRAFICO DE ENTORPECENTE
# 78    79  CIOPS       SIM                          OUTROS CRIMES DE TRANSITO
# 86    87  CIOPS       NÃO               VEICULO LOCALIZADO (ATO INFRACIONAL)
# 96    97  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 102  103  CIOPS       NÃO                                       MORTE A BALA
# 113  114  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 118  119  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 121  122  CIOPS       NÃO                ABANDONO DE MATERIAL OU BENS MOVEIS
# 128  129  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 137  138  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 143  144  CIOPS       SIM                           TRAFICO DE ENTORPECENTES
# 146  147  CIOPS       NÃO  VEICULO LOCALIZADO  ( ATO INFRACIONAL / FLAGRA...
# 161  162  CIOPS       NÃO                 APREENSAO DE ARMAS E ENTORPECENTES
# 162  163  CIOPS       NÃO             PORTE ILEGAL DE ARMA (ATO INFRACIONAL)
# 175  176  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 177  178  CIOPS       NÃO  MORTE A BALA / PORTE ILEGAL DE ARMA(ATO INFRAC...
# 195  196  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 205  206  CIOPS       NÃO                                       MORTE A BALA
# 216  217  CIOPS       SIM                              AGRESSAO VIAS DE FATO
# 220  221  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 226  227  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 228  229  CIOPS       NÃO                PORTE ILEGAL DE ARMA  ( FLAGRANTE )
# 232  233  CIOPS       SIM                                   ROUBO DE VEICULO
# ..   ...    ...       ...                                                ...
# 331  332  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 352  353  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 366  367  CIOPS       NÃO                                       MORTE A BALA
# 375  376  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 383  384  CIOPS       NÃO                  VEICULO LOCALIZADO  ( FLAGRANTE )
# 420  421  CIOPS       NÃO         MORTE A BALA SEGUIDA LESAO CORPORAL A BALA
# 428  429  CIOPS       NÃO  VEICULO DE VEICULO LOCALIZADO  (ATO INFRACIONA...
# 435  436  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 437  438  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 439  440  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 440  441  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 444  445  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 456  457  CIOPS       NÃO                                       MORTE A BALA
# 459  460  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 479  480  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 494  495  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 498  499  CIOPS       NÃO                                       MORTE A BALA
# 513  514  CIOPS       SIM                                     ROUBO A PESSOA
# 517  518  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 540  541  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 545  546  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 547  548  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 551  552  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 555  556  CIOPS       NÃO                                       MORTE A BALA
# 566  567  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 569  570  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 573  574  CIOPS       NÃO                                       MORTE A FACA
# 580  581  CIOPS       NÃO                               ABANDONO DE MATERIAL
# 600  601  CIOPS       NÃO             PORTE ILEGAL DE ARMA (ATO INFRACIONAL)
# 608  609  CIOPS       NÃO                                 VEICULO LOCALIZADO
#
#                                HISTÓRICO DA OCORRÊNCIA  \
# 15   LOCAL: RUA MIRTES CORDEIRO, BOM JARDIM.  VÍTIM...
# 17   LOCAL: RUA BOA JESUS, BOM JARDIM.VÍTIMA: ARMAN...
# 26   LOCAL: RUA DONZELA, JOÃO XXIII.  VEÍCULO: CG 1...
# 32   LOCAL: RUA OSCAR FRANCA, BOM JARDIM.  VÍTIMA: ...
# 53   LOCAL: RUA GERALDO BARBOSA, BOM JARDIM.  VEÍCU...
# 55   LOCAL: RUA NOVA CONQUITA, BOM JARDIM.  VEÍCULO...
# 73   LOCAL: RUA MONSENHOR AGOSTINHO, PARQUE SÃO JOS...
# 76   LOCAL: RUA ESTÊNIO GOMES, VILA PERY.  MATERIAL...
# 78   LOCAL: RUA EMÍLIO DE MENEZES, BONSUCESSO.  VEÍ...
# 86   LOCAL: AV. GENERAL OSÓRIO DE PAIVA, VILA PERI....
# 96   LOCAL: RUA AIRES DA CUNHA, GRANJA PORTUGAL.  V...
# 102  LOCAL: RUA SOUSA CARVALHO, GRANJA PORTUGAL.  V...
# 113  LOCAL: RUA VIRGÍLIO NOGUEIRA, BOM JARDIM.  VEÍ...
# 118  LOCAL: RUA MARIA JÚLIA ROCHA, BOM JARDIM.  VEÍ...
# 121  LOCAL: RUA MELO DE OLIVEIRA, JOÃO XXIII.  ARMA...
# 128  LOCAL: RUA SABINO FEIJÃO, BOM JARDIM.  VEÍCULO...
# 137  LOCAL: RUA VITAL BRASIL,GRANJA PORTUGAL. ARMA ...
# 143  LOCAL:RUAJÚLIOBRAGA,JOÃOXXIII.SUSPEITOS:1o RON...
# 146  LOCAL: RUA PRIMEIRO DE MAIO, GRANJA PORTUGAL.S...
# 161  LOCAL: RUA JOSÉ MARTINS, GRANJA LÍSBOA.  ARMA ...
# 162  LOCAL: RUA HUMBERTO LOMEU, GRANJA PORTUGAL.ARM...
# 175  LOCAL: RUA DOLORES DURAN, GRANJA PORTUGAL.  VE...
# 177  LOCAL: RUA MARIA DULCE, BOM SUCESSO. VÍTIMA: J...
# 195  LOCAL: RUA TEODORO DE CASTRO, GRANJA PORTUGAL....
# 205  LOCAL: RUA MARTINS DE CARVALHO, BOM JARDIM.  V...
# 216  LOCAL:RUASÃOJOÃO,JANGURUSSU.VÍTIMA:MARIAS.S.F....
# 220  LOCAL: RUA TEODORO DE CASTRO, GRANJA PORTUGAL....
# 226  LOCAL: RUA TAQUARI, BOM SUCESSO.  VEÍCULO: COR...
# 228  LOCAL:AV.GENERALOSÓRIO DE PAIVA,PARQUE SÃO JOS...
# 232  LOCAL: RUA JOÃO VINTE E TRÊS, GRANJA LÍSBOA.VE...
# ..                                                 ...
# 331  LOCAL: RUA FRANCISCO DOMINGOS,GENIBAÚ.ARMA APR...
# 352  LOCAL: RUA JOSÉ JÚLIO FROTA, BONSUCESSO.SUSPEI...
# 366  LOCAL: RUA GERALDO BARBOSA, BOM JARDIM.  VÍTIM...
# 375  LOCAL: RUA OSCAR ARARIPE, BOM JARDIM.  VEÍCULO...
# 383  LOCAL: AV. GENERAL OSÓRIO DE PAIVA, PARQUE SÃO...
# 420  LOCAL:RUACORONELFABRICIANO,GRANJAPORTUGAL.VÍTI...
# 428  LOCAL: RUA JÚLIO BRAGA, BOM SUCESSO.VEICULO: B...
# 435  LOCAL: RUA CARLOS CHAGAS, BOM SUCESSO.   VEICU...
# 437  LOCAL: RUA TAQUARI, BOM SUCESSO.   VEICULO: CA...
# 439  LOCAL: RUA COSMONAUTA, BOM SUCESSO.   VEICULO:...
# 440  LOCAL: RUA ALUÍSIO AZEVEDO, JOÃO XXIII.   VEIC...
# 444  LOCAL: RUA FRANCISCO PAIVA, GRANJA LISBOA.   V...
# 456  LOCAL: RUA VALVERDE, BOM JARDIM.  VÍTIMA: FRAN...
# 459  LOCAL: RUA NEREIDE, BOM JARDIM.  VEÍCULO: CG 1...
# 479  LOCAL: AV. BARRA VERMELHA, BOM JARDIM.ARMA APR...
# 494  LOCAL: RUA PERDIGÃO DE OLIVEIRA, JÓQUEI CLUBE....
# 498  LOCAL: RUA ARAÇÁ, BOM SUCESSO.  VÍTIMA: MARCOS...
# 513  LOCAL: RUA AUGUSTO DOS ANJOS, PARANGABA.VÍTIMA...
# 517  LOCAL: RUA RISO DO PRADO, BOM SUCESSO.  VEÍCUL...
# 540  LOCAL: RUA DOLORES DURAN, GRANJA PORTUGAL. VEÍ...
# 545  LOCAL: RUA FÉLIX CANDIDO, BONSUCESSO. VEÍCULO:...
# 547  LOCAL: RUA TEODORO DE CASTRO, GRANHA PORTUGAL....
# 551  LOCAL: RUA UNIFLOR, BONJARDIM. VEÍCULO: MOTOCI...
# 555  LOCAL: RUA SABINO FEIJÃO, GRANJA PORTUGAL.  VÍ...
# 566  LOCAL: RUA OSCAR ARARIPE, GRANJA LISBOA.  VEÍC...
# 569  LOCAL: RUA SEIXAS CORREIA, VILA PERI.  VEICULO...
# 573  LOCAL: RUA GUSTAVO BARROSO, BOM JARDIM.  VÍTIM...
# 580  LOCAL:RUAMARIAJÚLIA,BOMJARDIM.ARMAAPREENDIDA:R...
# 600  LOCAL:RUAARIMAIA,GRANJALISBOA.ARMAAPREENDIDA:R...
# 608  LOCAL: RUA OSCAR ARARIPE, GRANJA LISBOA.  VEÍC...
#
#                                            LOCAL:           BAIRRO  \
# 15                RUA MIRTES CORDEIRO, BOM JARDIM       BOM JARDIM
# 17                      RUA BOA JESUS, BOM JARDIM       BOM JARDIM
# 26                        RUA DONZELA, JOAO XXIII       JOAO XXIII
# 32                   RUA OSCAR FRANCA, BOM JARDIM       BOM JARDIM
# 53                RUA GERALDO BARBOSA, BOM JARDIM       BOM JARDIM
# 55                  RUA NOVA CONQUITA, BOM JARDIM       BOM JARDIM
# 73       RUA MONSENHOR AGOSTINHO, PARQUE SAO JOSE  PARQUE SAO JOSE
# 76                   RUA ESTENIO GOMES, VILA PERY        VILA PERY
# 78              RUA EMILIO DE MENEZES, BONSUCESSO       BONSUCESSO
# 86         AV. GENERAL OSORIO DE PAIVA, VILA PERI        VILA PERI
# 96            RUA AIRES DA CUNHA, GRANJA PORTUGAL  GRANJA PORTUGAL
# 102           RUA SOUSA CARVALHO, GRANJA PORTUGAL  GRANJA PORTUGAL
# 113             RUA VIRGILIO NOGUEIRA, BOM JARDIM       BOM JARDIM
# 118             RUA MARIA JULIA ROCHA, BOM JARDIM       BOM JARDIM
# 121              RUA MELO DE OLIVEIRA, JOAO XXIII       JOAO XXIII
# 128                 RUA SABINO FEIJAO, BOM JARDIM       BOM JARDIM
# 137              RUA VITAL BRASIL,GRANJA PORTUGAL  GRANJA PORTUGAL
# 143                       RUAJULIOBRAGA,JOAOXXIII        JOAOXXIII
# 146         RUA PRIMEIRO DE MAIO, GRANJA PORTUGAL  GRANJA PORTUGAL
# 161               RUA JOSE MARTINS, GRANJA LISBOA    GRANJA LISBOA
# 162           RUA HUMBERTO LOMEU, GRANJA PORTUGAL  GRANJA PORTUGAL
# 175            RUA DOLORES DURAN, GRANJA PORTUGAL  GRANJA PORTUGAL
# 177                  RUA MARIA DULCE, BOM SUCESSO      BOM SUCESSO
# 195        RUA TEODORO DE CASTRO, GRANJA PORTUGAL  GRANJA PORTUGAL
# 205           RUA MARTINS DE CARVALHO, BOM JARDIM       BOM JARDIM
# 216                         RUASAOJOAO,JANGURUSSU       JANGURUSSU
# 220        RUA TEODORO DE CASTRO, GRANJA PORTUGAL  GRANJA PORTUGAL
# 226                      RUA TAQUARI, BOM SUCESSO      BOM SUCESSO
# 228     AV.GENERALOSORIO DE PAIVA,PARQUE SAO JOSE  PARQUE SAO JOSE
# 232          RUA JOAO VINTE E TRES, GRANJA LISBOA    GRANJA LISBOA
# ..                                            ...              ...
# 331                RUA FRANCISCO DOMINGOS,GENIBAU          GENIBAU
# 352              RUA JOSE JULIO FROTA, BONSUCESSO       BONSUCESSO
# 366               RUA GERALDO BARBOSA, BOM JARDIM       BOM JARDIM
# 375                 RUA OSCAR ARARIPE, BOM JARDIM       BOM JARDIM
# 383  AV. GENERAL OSORIO DE PAIVA, PARQUE SAO JOSE  PARQUE SAO JOSE
# 420           RUACORONELFABRICIANO,GRANJAPORTUGAL   GRANJAPORTUGAL
# 428                  RUA JULIO BRAGA, BOM SUCESSO      BOM SUCESSO
# 435                RUA CARLOS CHAGAS, BOM SUCESSO      BOM SUCESSO
# 437                      RUA TAQUARI, BOM SUCESSO      BOM SUCESSO
# 439                   RUA COSMONAUTA, BOM SUCESSO      BOM SUCESSO
# 440               RUA ALUISIO AZEVEDO, JOAO XXIII       JOAO XXIII
# 444            RUA FRANCISCO PAIVA, GRANJA LISBOA    GRANJA LISBOA
# 456                      RUA VALVERDE, BOM JARDIM       BOM JARDIM
# 459                       RUA NEREIDE, BOM JARDIM       BOM JARDIM
# 479                AV. BARRA VERMELHA, BOM JARDIM       BOM JARDIM
# 494        RUA PERDIGAO DE OLIVEIRA, JOQUEI CLUBE     JOQUEI CLUBE
# 498                        RUA ARACA, BOM SUCESSO      BOM SUCESSO
# 513              RUA AUGUSTO DOS ANJOS, PARANGABA        PARANGABA
# 517                RUA RISO DO PRADO, BOM SUCESSO      BOM SUCESSO
# 540            RUA DOLORES DURAN, GRANJA PORTUGAL  GRANJA PORTUGAL
# 545                 RUA FELIX CANDIDO, BONSUCESSO       BONSUCESSO
# 547        RUA TEODORO DE CASTRO, GRANHA PORTUGAL  GRANHA PORTUGAL
# 551                        RUA UNIFLOR, BONJARDIM        BONJARDIM
# 555            RUA SABINO FEIJAO, GRANJA PORTUGAL  GRANJA PORTUGAL
# 566              RUA OSCAR ARARIPE, GRANJA LISBOA    GRANJA LISBOA
# 569                 RUA SEIXAS CORREIA, VILA PERI        VILA PERI
# 573               RUA GUSTAVO BARROSO, BOM JARDIM       BOM JARDIM
# 580                       RUAMARIAJULIA,BOMJARDIM        BOMJARDIM
# 600                       RUAARIMAIA,GRANJALISBOA     GRANJALISBOA
# 608              RUA OSCAR ARARIPE, GRANJA LISBOA    GRANJA LISBOA
#
#                                              SUSPEITO:  \
# 15                                                nulo
# 17                                                nulo
# 26                                                nulo
# 32                                                nulo
# 53                                                nulo
# 55                                                nulo
# 73                                                nulo
# 76                                                nulo
# 78        FRANCISCO DIEGO DE OLIVEIRA MARIANO, 26 ANOS
# 86                                                nulo
# 96                                                nulo
# 102                                               nulo
# 113                                               nulo
# 118                                               nulo
# 121                                               nulo
# 128                                               nulo
# 137  LÚCIO SILVA DO NASCIMENTO, 38 ANOS\nFOI CONDUZ...
# 143                                               nulo
# 146                                               nulo
# 161                                               nulo
# 162                                               nulo
# 175                                               nulo
# 177                                     MENOR DE IDADE
# 195  FERNANDO VITORINO DA SILVA, 23 ANOS, FOI CONDU...
# 205                                               nulo
# 216  ADAILTONDESOUZAFERREIRA,33ANOS,FOICONDUZIDOÀDE...
# 220                                               nulo
# 226                                               nulo
# 228                   JOSÉEDSON ALVE\nPEREIRA, 50 ANOS
# 232                                               nulo
# ..                                                 ...
# 331           FRANCISCO RONALDO MOTA D\nSILVA, 23 ANOS
# 352                                               nulo
# 366                                               nulo
# 375                                               nulo
# 383                     BRUNO ALVES RODRIGUES\n18 ANOS
# 420                                               nulo
# 428                                               nulo
# 435                                               nulo
# 437                                               nulo
# 439                                               nulo
# 440                                               nulo
# 444                                               nulo
# 456                                               nulo
# 459                                               nulo
# 479                                               nulo
# 494                                               nulo
# 498                                               nulo
# 513                                               nulo
# 517                                               nulo
# 540                                               nulo
# 545                                               nulo
# 547                                               nulo
# 551                                               nulo
# 555                                   NÃO IDENTIFICADO
# 566                                               nulo
# 569                                               nulo
# 573                                   NÃO IDENTIFICADO
# 580                                               nulo
# 600                                               nulo
# 608                                               nulo
#
#                                               VEÍCULO:  \
# 15                                                nulo
# 17                                                nulo
# 26                 CG 125 FAN, PRETA, 2008, HYH9247-CE
# 32                                                nulo
# 53                CORSA WIND, PRETA, 96/97, HVL6249-CE
# 55                FAN ESI, VERMELHA, 09/10, NQR7107-CE
# 73                                                nulo
# 76                                                nulo
# 78        TITAN, VERMELHA, SEM PLACA E CHASSI ILEGÍVEL
# 86              FAN KS, 2011, VERMELHA, PLACA: OCE0085
# 96                GOL 16V, CINZA, 1998, PLACA: HWF1718
# 102                                               nulo
# 113               CG150 FAN ESDI, PRETA, 2015, OSN4330
# 118                       GOL CL, PRATA, 1994, HUJ4266
# 121                                               nulo
# 128                   PALIO, PRATA, 2013/2014, OQA3794
# 137                                               nulo
# 143                                               nulo
# 146                                               nulo
# 161                                               nulo
# 162                                               nulo
# 175             CELTA 2P LIFE, 2005, PRATA, HUW3718-CE
# 177                                               nulo
# 195                                               nulo
# 205                                               nulo
# 216                                               nulo
# 220                   8160 DRC 4X2, BRANCO, PMM7210-CE
# 226                      CORSA WIND,01,AZUL,MXL3586-CE
# 228                                               nulo
# 232                           GOL VERMELHO, MNY0718-CE
# ..                                                 ...
# 331                                               nulo
# 352                                               nulo
# 366                                               nulo
# 375               CORSA WIND, BRANCA, 2000, HWE5123-CE
# 383                                         NOVO GOL 1
# 420                                               nulo
# 428                                               nulo
# 435                                               nulo
# 437                                               nulo
# 439                                               nulo
# 440                                               nulo
# 444                                           PRISMA 1
# 456                                               nulo
# 459     CG 150 TITAN KS, AZUL, 2008/2008 , HYA 3696-CE
# 479                                               nulo
# 494                     FAN ESI, 12, VERMELHA, OCF3269
# 498                                               nulo
# 513                                               nulo
# 517                                      ECOSPORT XLS1
# 540         CLASSIC SPIRIT, 2008, CINZA, PLACA HYF9695
# 545         XTZ 125XK, PRETA, 2008/2009, PLACA KZA1741
# 547                 KADETT SL/E, MARROM, 1989, HUY2817
# 551  MOTOCICLETA 50CC XY 50Q PHOENIX, CHASSI LXYXCB...
# 555                                               nulo
# 566                                              FOX 1
# 569                                               nulo
# 573                                               nulo
# 580                                               nulo
# 600                                               nulo
# 608                      KOMBI, 09, BRANCA, HYD1706-CE
#
#                                VÍTIMA:   ...       MATERIAL APREENDIDO:  \
# 15                             ELTON D   ...                       nulo
# 17                           ARMANDO C   ...                       nulo
# 26                                nulo   ...                       nulo
# 32                            GERSON P   ...                       nulo
# 53                                nulo   ...                       nulo
# 55                                nulo   ...                       nulo
# 73                                nulo   ...                       nulo
# 76                                nulo   ...                      CRACK
# 78                                nulo   ...    UM SIMULACRO DE PISTOLA
# 86                                nulo   ...                       nulo
# 96                                nulo   ...                       nulo
# 102                        JEFFERSON P   ...                       nulo
# 113                               nulo   ...                       nulo
# 118                               nulo   ...                       nulo
# 121                               nulo   ...                       nulo
# 128                               nulo   ...                       nulo
# 137                               nulo   ...                       nulo
# 143                               nulo   ...                       nulo
# 146                               nulo   ...                       nulo
# 161                               nulo   ...                       nulo
# 162                               nulo   ...                       nulo
# 175                               nulo   ...                       nulo
# 177                          JOSÉ A, P   ...                       nulo
# 195                               nulo   ...                       nulo
# 205                             JOSÉ W   ...                       nulo
# 216                             MARIAS   ...                       nulo
# 220                               nulo   ...                       nulo
# 226                               nulo   ...                       nulo
# 228                               nulo   ...                       nulo
# 232                               nulo   ...                       nulo
# ..                                 ...   ...                        ...
# 331                               nulo   ...                       nulo
# 352                               nulo   ...                       nulo
# 366                         CLEILTON A   ...                       nulo
# 375                               nulo   ...                       nulo
# 383                               nulo   ...                       nulo
# 420                               nulo   ...                       nulo
# 428                           SANDRA S   ...                       nulo
# 435                               nulo   ...                       nulo
# 437                               nulo   ...                       nulo
# 439                               nulo   ...                       nulo
# 440                               nulo   ...                       nulo
# 444                               nulo   ...                       nulo
# 456                        FRANCISCO B   ...                       nulo
# 459                               nulo   ...                       nulo
# 479                               nulo   ...                       nulo
# 494                               nulo   ...                       nulo
# 498                          MARCOS VS   ...                       nulo
# 513                     MENOR DE IDADE   ...                       nulo
# 517                               nulo   ...                       nulo
# 540                               nulo   ...                       nulo
# 545                               nulo   ...                       nulo
# 547                               nulo   ...                       nulo
# 551                               nulo   ...                       nulo
# 555                     MENOR DE IDADE   ...                       nulo
# 566                               nulo   ...                       nulo
# 569                               nulo   ...                       nulo
# 573  SEXO MASCULINO, SEM IDENTIFICAÇAO   ...                       nulo
# 580                               nulo   ...                       nulo
# 600                               nulo   ...                       nulo
# 608                               nulo   ...                       nulo
#
#          PLACA: VÍTIMAS LESIONADAS:  \
# 15         nulo                nulo
# 17         nulo                nulo
# 26         nulo                nulo
# 32         nulo                nulo
# 53         nulo                nulo
# 55         nulo                nulo
# 73         nulo                nulo
# 76         nulo                nulo
# 78         nulo                nulo
# 86      OCE0085                nulo
# 96      HWF1718                nulo
# 102        nulo                nulo
# 113        nulo                nulo
# 118        nulo                nulo
# 121        nulo                nulo
# 128        nulo                nulo
# 137        nulo                nulo
# 143        nulo                nulo
# 146        nulo                nulo
# 161        nulo                nulo
# 162        nulo                nulo
# 175        nulo                nulo
# 177        nulo                nulo
# 195        nulo                nulo
# 205        nulo                nulo
# 216        nulo                nulo
# 220        nulo                nulo
# 226        nulo                nulo
# 228        nulo                nulo
# 232        nulo                nulo
# ..          ...                 ...
# 331        nulo                nulo
# 352        nulo                nulo
# 366        nulo                nulo
# 375        nulo                nulo
# 383        nulo                nulo
# 420        nulo                nulo
# 428  PNB6780-CE                nulo
# 435     HZA5972                nulo
# 437     KIS8808                nulo
# 439     JSG5908                nulo
# 440     ORU4238                nulo
# 444  PMM9041-CE                nulo
# 456        nulo                nulo
# 459        nulo                nulo
# 479        nulo                nulo
# 494        nulo                nulo
# 498        nulo                nulo
# 513        nulo                nulo
# 517  HXX3037-CE                nulo
# 540        nulo                nulo
# 545        nulo                nulo
# 547        nulo                nulo
# 551        nulo                nulo
# 555        nulo                nulo
# 566        nulo                nulo
# 569        nulo                nulo
# 573        nulo                nulo
# 580        nulo                nulo
# 600        nulo                nulo
# 608        nulo                nulo
#
#                                             SUSPEITOS: HORA MINUTO      DATA  \
# 15                                   NÃO IDENTIFICADOS   17     31  02/03/17
# 17      1o- THAIAN FRANCISCO DE JESUS BEZERRA, 20 ANOS   15     39  02/03/17
# 26                                                nulo   15     48  02/03/17
# 32                                                nulo   20     53  03/03/17
# 53                                                nulo   15     43  03/03/17
# 55                                                nulo   16     57  03/03/17
# 73   1o – ELPSON JEOVÁ DA FONSECA MENEZES, 23 ANOS,...    1      4  04/03/17
# 76                                                nulo   20     41  04/03/17
# 78                                                nulo   23     41  04/03/17
# 86                               DOIS MENORES DE IDADE   12     53  04/03/17
# 96                                                nulo   20     15  04/03/17
# 102                    QUATRO HOMENS NÃO IDENTIFICADOS   17     31  05/03/17
# 113                                               nulo   14      6  05/03/17
# 118                                               nulo   20     39  05/03/17
# 121                                               nulo   22     39  06/03/17
# 128                                               nulo    9     39  06/03/17
# 137                                               nulo   22     10  07/03/17
# 143                 1o RONALISSONDOSSANTOSSOUSA,22ANOS   21      7  07/03/17
# 146                                  1o MENOR DE IDADE   12     17  07/03/17
# 161                                               nulo   20     56  08/03/17
# 162                                       DOIS MENORES   23     50  08/03/17
# 175                                               nulo   19     23  08/03/17
# 177                                               nulo   14     44  10/03/17
# 195                                               nulo   21      7  11/03/17
# 205                                        DOIS HOMENS   21     55  12/03/17
# 216                                               nulo    8     24  12/03/17
# 220                                               nulo    6     26  12/03/17
# 226                                               nulo   20     10  12/03/17
# 228                                               nulo    8     53  13/03/17
# 232      1o CÁSSIO JANDERSON DA SILVA MARTINS, 1\nANOS   15     48  13/03/17
# ..                                                 ...  ...    ...       ...
# 331                                               nulo   11      4  18/03/17
# 352  1o- JEFFERSON DA SILVA ARAGÃO, 26 ANOS; 2o- ED...   15     27  19/03/17
# 366                        NADA FOI INFORMADO NO LOCAL   18     37  20/03/17
# 375                                               nulo    8     48  20/03/17
# 383                                               nulo   15     49  20/03/17
# 420                                  NÃO IDENTIFICADOS   18      8  22/03/17
# 428  1o – MENOR\nDE IDADE, 2o – LUIZ HENRIQUE DA SI...    9     49  22/03/17
# 435                                               nulo    7     46  22/03/17
# 437                                               nulo   10     23  22/03/17
# 439                                               nulo   13     57  22/03/17
# 440                                               nulo   14     34  22/03/17
# 444                                               nulo   21     42  22/03/17
# 456                                  NÃO IDENTIFICADOS   17     49  24/03/17
# 459                                               nulo   15      5  24/03/17
# 479            1o ANTÔNIO DIEGO BEZERRA VIANA, 22 ANOS   14     51  26/03/17
# 494                                               nulo   21     32  26/03/17
# 498                                  NÃO IDENTIFICADOS   19     42  27/03/17
# 513  1o - RAFAEL SANTOS DE ALCANTARA, 25 ANOS, 2o- ...   18     55  27/03/17
# 517                                               nulo   10     28  27/03/17
# 540                                               nulo   10     51  28/03/17
# 545                                               nulo   15      6  28/03/17
# 547                                               nulo   18     16  28/03/17
# 551                                               nulo   19     31  28/03/17
# 555                                               nulo   18     18  29/03/17
# 566                                               nulo   13     42  29/03/17
# 569                                               nulo   19     57  29/03/17
# 573                                               nulo   13     24  30/03/17
# 580                                               nulo   23     14  30/03/17
# 600                                               nulo   19     22  31/03/17
# 608                                               nulo   13     30  31/03/17
#
#      LATITUDE  LONGITUDE CLUSTER
# 15  -3.788606 -38.600321       4
# 17  -3.794164 -38.602067       4
# 26  -3.770396 -38.593709       4
# 32  -3.791422 -38.601130       4
# 53  -3.792443 -38.600382       4
# 55  -3.792339 -38.609988       4
# 73  -3.796074 -38.590375       4
# 76  -3.790784 -38.582217       4
# 78  -3.781358 -38.588833       4
# 86  -3.789813 -38.587485       4
# 96  -3.779082 -38.604814       4
# 102 -3.779761 -38.602324       4
# 113 -3.790290 -38.609302       4
# 118 -3.796332 -38.600965       4
# 121 -3.773817 -38.578894       4
# 128 -3.795727 -38.597307       4
# 137 -3.779029 -38.594431       4
# 143 -3.774297 -38.583110       4
# 146 -3.781185 -38.594670       4
# 161 -3.784044 -38.616895       4
# 162 -3.781712 -38.603613       4
# 175 -3.785112 -38.593230       4
# 177 -3.775131 -38.584165       4
# 195 -3.779766 -38.605010       4
# 205 -3.795818 -38.602635       4
# 216 -3.772132 -38.595104       4
# 220 -3.779766 -38.605010       4
# 226 -3.779954 -38.588448       4
# 228 -3.792422 -38.590017       4
# 232 -3.782772 -38.616537       4
# ..        ...        ...     ...
# 331 -3.777347 -38.592448       4
# 352 -3.785404 -38.584725       4
# 366 -3.792443 -38.600382       4
# 375 -3.791139 -38.599492       4
# 383 -3.792422 -38.590017       4
# 420 -3.785001 -38.599927       4
# 428 -3.775117 -38.582190       4
# 435 -3.778539 -38.590770       4
# 437 -3.779954 -38.588448       4
# 439 -3.787611 -38.588881       4
# 440 -3.769707 -38.579983       4
# 444 -3.790231 -38.614107       4
# 456 -3.792495 -38.604702       4
# 459 -3.786858 -38.601054       4
# 479 -3.785554 -38.614140       4
# 494 -3.774698 -38.577897       4
# 498 -3.781497 -38.583770       4
# 513 -3.778426 -38.577646       4
# 517 -3.778681 -38.582371       4
# 540 -3.785112 -38.593230       4
# 545 -3.768996 -38.577737       4
# 547 -3.779766 -38.605010       4
# 551 -3.796666 -38.602526       4
# 555 -3.788482 -38.595127       4
# 566 -3.786786 -38.612991       4
# 569 -3.779142 -38.578900       4
# 573 -3.786570 -38.597129       4
# 580 -3.797558 -38.601314       4
# 600 -3.784579 -38.621753       4
# 608 -3.786786 -38.612991       4
#
# [72 rows x 23 columns]

# %% [markdown]
# ### Uma análise sobre as 5 ocorrências mais comuns

# %%
crime_types = regiao_4_detalhe[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = regiao_4_detalhe[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5 = all_crime_types.head(5)
crimes_top_5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes na região 4')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 horários com mais ocorrências em março

# %%
horas_mes = df_marco.HORA.value_counts()
horas_mes_top10 = horas_mes.head(10)

# %%
horas_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Crimes por hora (Mar 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 5 horários com mais ocorrências na região 4 (região com mais ocorrências em março)

# %%
crime_hours = regiao_4_detalhe[['HORA']]
crime_hours_total = crime_hours.groupby('HORA').size()
crime_hours_counts = regiao_4_detalhe[['HORA']].groupby('HORA').sum()
crime_hours_counts['TOTAL'] = crime_hours_total
all_hours_types = crime_hours_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_hours_types.head(5)
# Out:
#       TOTAL
# HORA
# 15        9
# 20        7
# 10        6
# 21        5
# 19        5

# %%
all_hours_types_top5 = all_hours_types.head(5)
all_hours_types_top5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes por hora na região 4')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 bairros com mais ocorrências em março

# %%
crimes_mes = df_marco.BAIRRO.value_counts()
crimes_mes_top10 = crimes_mes.head(10)

# %%
crimes_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Top 10 Bairros com mais crimes (Mar 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### O Bairro com o maior número de ocorrências em março foi Jangurussu

# %% [markdown]
# ### Vamos agora ver de forma mais detalhadas quais foram estes crimes

# %%
messejana = df_marco[df_marco['BAIRRO'] == 'JANGURUSSU']
crime_types = messejana[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = messejana[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes no Jangurussú')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Os 5 bairros mais comuns na região 4

# %%
crime_types_bairro = regiao_4_detalhe[['BAIRRO']]
crime_type_total_bairro = crime_types_bairro.groupby('BAIRRO').size()
crime_type_counts_bairro = regiao_4_detalhe[['BAIRRO']].groupby('BAIRRO').sum()
crime_type_counts_bairro['TOTAL'] = crime_type_total_bairro
all_crime_types_bairro = crime_type_counts_bairro.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5_bairro = all_crime_types_bairro.head(5)
crimes_top_5_bairro.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 bairros na região 4')
plt.xlabel('Quantidade')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Análise sobre o bairro Bom Jardim

# %%
bom_jardim = df_marco[df_marco['BAIRRO'] == 'BOM JARDIM']
crime_types = bom_jardim[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = bom_jardim[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes no Bom Jardim')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
