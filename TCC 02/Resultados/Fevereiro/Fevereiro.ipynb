# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df_fevereiro = pandas.read_csv("./data/Cluster-Crime-Fevereiro.csv")

# %%
crime_tipos = df_fevereiro[['NATUREZA DA OCORRÊNCIA']]
crime_tipo_total = crime_tipos.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_tipo_counts = df_fevereiro[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_tipo_counts['TOTAL'] = crime_tipo_total
all_crime_tipos = crime_tipo_counts.sort_values(by='TOTAL', ascending=False)

# %% [markdown]
# ### Filtro dos 10 crimes com mais ocorrências em fevereiro

# %%
all_crime_tipos.head(10)
# Out:
#                                         TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                        193
# MORTE A BALA                               42
# PORTE ILEGAL DE ARMA                       27
# ROUBO A PESSOA                             17
# CUMPRIMENTO DE MANDADO JUDICIAL            16
# TRAFICO DE ENTORPECENTES                   13
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)      8
# MORTE A OUTROS                              6
# VEICULO LOCALIZADO  (ATO INFRACIONAL)       6
# TRAFICO DE ENTORPECENTE                     5

# %%
all_crime_tipos_top10 = all_crime_tipos.head(10)
all_crime_tipos_top10.plot(kind='barh', figsize=(12,6), color='#3f3fff')
plt.title('Top 10 crimes por tipo (Fev 2017)')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Todas as ocorrências criminais de fevereiro

# %%
all_crime_tipos
# Out:
#                                                     TOTAL
# NATUREZA DA OCORRÊNCIA
# VEICULO LOCALIZADO                                    193
# MORTE A BALA                                           42
# PORTE ILEGAL DE ARMA                                   27
# ROUBO A PESSOA                                         17
# CUMPRIMENTO DE MANDADO JUDICIAL                        16
# TRAFICO DE ENTORPECENTES                               13
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL)                  8
# MORTE A OUTROS                                          6
# VEICULO LOCALIZADO  (ATO INFRACIONAL)                   6
# TRAFICO DE ENTORPECENTE                                 5
# TRAFICO DE ENTORPECENTES (ATO INFRACIONAL)              5
# APREENSAO DE ARMA                                       5
# PORTE ILEGAL DE ARMA  ( FLAGRANTE )                     4
# VEICULOS LOCALIZADOS                                    4
# APREENSAO DE ARMA E DROGA                               4
# VEICULO LOCALIZADO (ATO INFRACIONAL)                    3
# EMBRIAGUEZ AO VOLANTE                                   3
# TRAFICO DE ENTORPECENTES ( FLAGRANTE )                  3
# FURTO A ESTABELECIMENTO                                 3
# ROUBO A PESSOA (ATO INFRACIONAL)                        2
# ROUBO DE VEICULO                                        2
# MORTE A FACA                                            2
# PORTE ILEGAL DE ARMA (FLAGRANTE / ATO INFRACIONAL)      2
# TENTATIVA DE ROUBO A PESSOA                             2
# TRAFICO DE ENTORPECENTE  (ATO INFRACIONAL)              2
# PORTE ILEGAL DE ARMA (ATO INFRACIONAL/FLAGRANTE)        2
# LESAO CORPORAL A FACA                                   2
# ABANDONO DE MATERIAL / ENTORPECENTES APREENDIDO...      2
# MORTE A BALA  LESAO CORPORAL A BALA                     2
# VEICULO LOCALIZADO (TCO)                                2
# ...                                                   ...
# AGRESSAO/VIAS DE FATO (ATO INFRACIONAL)                 1
# AGRESSAO/VIAS DE FATO                                   1
# MORTE A BALA  SEGUIDO DE LESAO CORPORAL                 1
# MORTE A BALA / ARMA APREENDIDA                          1
# MORTE A PAULADAS                                        1
# MUNICAO APREEENDIDA  FLAGRANTE                          1
# ROUBO A ESTABELECIMENTO  ARMA APREENDIDA (ATO I...      1
# ROUBO A ESTABELECIMENTO                                 1
# ROUBO A COLETIVO (ATO INFRACIONAL)                      1
# ROUBO A COLETIVO (ATO INFRACIONAL / FLAGRANTE)          1
# ROUBO A COLETIVO  (ATO INFRACIONAL)                     1
# ROUBO A COLETIVO  ( ATO INFRACIONAL )                   1
# ABANDONO DE MATERIAL OU BENS MOVEIS  (DROGA APR...      1
# ROUBO  DE VEICULO                                       1
# ROUBO  A PESSOA (FLAGRANTE E ATO INFRACINAL)            1
# ROUBO  A PESSOA                                         1
# RECEPTACAO  (FLAGRANTE / AUTO DE APREENSAO)             1
# RECEPTACAO  (ATO INFRACIONAL)                           1
# PORTE ILEGAL DE ARMAS  ( FLAGRANTE )                    1
# PORTE ILEGAL DE ARMA BRANCA(TCO)                        1
# PORTE ILEGAL DE ARMA / VEICULO LOCALIZADO               1
# PORTE ILEGAL DE ARMA / TRAFICO DE ENTORPECENTES         1
# PORTE ILEGAL DE ARMA (MUNICAO)                          1
# PORTE ILEGAL DE ARMA (AUTO DE APREENSAO)                1
# PORTE ILEGAL DE ARMA  TRAFICO DE COCAINA  ( FLA...      1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL)                 1
# PORTE ILEGAL DE ARMA  (ATO INFRACIONAL / FLAGRA...      1
# PORTE ILEGAL DE ARMA  (ARMAS APREENDIDAS/ FLAGR...      1
# PESSOA EM SITUACAO SUSPEITA                             1
# VEICULOS LOCALIZADOS (BOC)                              1
#
# [128 rows x 1 columns]

# %% [markdown]
# ### Quantidade de crimes por região

# %%
group_df_fevereiro = df_fevereiro.groupby('CLUSTER')
crimes = group_df_fevereiro['NATUREZA DA OCORRÊNCIA'].count()

# %%
crimes.plot(kind='barh', figsize=(10,7), color='#3f3fff')
plt.title('Número de crimes por região (Fev 2017)')
plt.xlabel('Número')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### As 5 regiões com mais ocorrências

# %%
regioes = df_fevereiro.groupby('CLUSTER').count()
grupo_de_regioes = regioes.sort_values('NATUREZA DA OCORRÊNCIA', ascending=False)

# %%
grupo_de_regioes['TOTAL'] = grupo_de_regioes.ID
top_5_regioes_qtd = grupo_de_regioes.TOTAL.head(6)

# %%
top_5_regioes_qtd.plot(kind='barh', figsize=(10,4), color='#3f3fff')
plt.title('Top 5 regiões com mais crimes')
plt.xlabel('Número de crimes')
plt.ylabel('Região')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Acima podemos ver que a região 3 teve o maior número de ocorrências criminais

# %% [markdown]
# ### Podemos agora ver quais são essas ocorrências de forma mais detalhada

# %%
regiao_3_detalhe = df_fevereiro[df_fevereiro['CLUSTER'] == 3]
regiao_3_detalhe
# Out:
#       ID  FONTE FLAGRANTE                             NATUREZA DA OCORRÊNCIA  \
# 2      3  CIOPS       NÃO                                       MORTE A BALA
# 10    11  CIOPS       NÃO                VEICULO LOCALIZADO(ATO INFRACIONAL)
# 11    12  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 13    14  CIOPS       NÃO                                       MORTE A BALA
# 15    16  CIOPS       NÃO                                       MORTE A BALA
# 40    41  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 52    53  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 54    55  CIOPS       NÃO              VEICULO LOCALIZADO  (ATO INFRACIONAL)
# 55    56  CIOPS       NÃO              VEICULO LOCALIZADO  (ATO INFRACIONAL)
# 68    69  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 75    76  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 82    83  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 84    85  CIOPS       NÃO   VEICULO LOCALIZADO (ATO INFRACIONAL / FLAGRANTE)
# 89    90  CIOPS       NÃO                PORTE ILEGAL DE ARMA  ( FLAGRANTE )
# 90    91  CIOPS       NÃO                PORTE ILEGAL DE ARMA  ( FLAGRANTE )
# 97    98  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 103  104  CIOPS       NÃO                                       MORTE A BALA
# 106  107  CIOPS       NÃO  ROUBO A RESIDENCIA / ARMAS APREENDIDAS (ATO IN...
# 119  120  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 127  128  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 142  143  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 144  145  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 147  148  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 150  151  CIOPS       SIM                               PORTE ILEGAL DE ARMA
# 157  158  CIOPS       SIM                           TRAFICO DE ENTORPECENTES
# 164  165  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 172  173  CIOPS       NÃO                                       MORTE A BALA
# 193  194  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 194  195  CIOPS       SIM                                   ROUBO DE VEICULO
# 197  198  CIOPS       NÃO                                 VEICULO LOCALIZADO
# ..   ...    ...       ...                                                ...
# 208  209  CIOPS       SIM                           TRAFICO DE ENTORPECENTES
# 209  210  CIOPS       NÃO                            DIRECAO PERIGOSA  (TCO)
# 215  216  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 218  219  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 250  251  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 257  258  CIOPS       NÃO                                     MORTE A OUTROS
# 274  275  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 277  278  CIOPS       NÃO              VEICULO LOCALIZADO  (ATO INFRACIONAL)
# 284  285  CIOPS       SIM                           TRAFICO DE ENTORPECENTES
# 298  299  CIOPS       NÃO                                       MORTE A BALA
# 314  315  CIOPS       NÃO        ROUBO A PESSOA(ATO INFRACIONAL / FLAGRANTE)
# 317  318  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 322  323  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 323  324  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 326  327  CIOPS       SIM                            ROUBO A ESTABELECIMENTO
# 329  330  CIOPS       SIM                              EMBRIAGUEZ AO VOLANTE
# 331  332  CIOPS       NÃO                   ROUBO A PESSOA (ATO INFRACIONAL)
# 335  336  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 337  338  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 339  340  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 340  341  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 342  343  CIOPS       NÃO                                       MORTE A BALA
# 365  366  CIOPS       SIM                                 VEICULO LOCALIZADO
# 409  410  CIOPS       NÃO         TRAFICO DE ENTORPECENTES (ATO INFRACIONAL)
# 415  416  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 416  417  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 420  421  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 445  446  CIOPS       NÃO              ROUBO A COLETIVO  ( ATO INFRACIONAL )
# 490  491  CIOPS       NÃO                                 VEICULO LOCALIZADO
# 491  492  CIOPS       NÃO                                 VEICULO LOCALIZADO
#
#                                HISTÓRICO DA OCORRÊNCIA  \
# 2    LOCAL: RUA ALAGOAS, PICI. VÍTIMAS: 1o FRANCISC...
# 10   LOCAL: RUA PERNAMBUCO, PICI. VEÍCULO: YBR 125K...
# 11   LOCAL: RUA QUATRO DE DEZEMBRO, PICI. VEÍCULO: ...
# 13   LOCAL: RUA L, VILA VELHA.  VÍTIMA: JONATHAN B....
# 15   LOCAL: AV. MAJOR ASSIS, JARDIM GUANABARA.  VÍT...
# 40   LOCAL: RUA PEDRO MELO, ANTÔNIO BEZERRA.  VEICU...
# 52   LOCAL: RUA RAIMUNDO CUNHA, VILA VELHA.  VEÍCUL...
# 54   LOCAL: RUA ANTONIETA CLOTILDE, JARDIM IRACEMA....
# 55   LOCAL: RUA SÃO DOMINGOS, ANTÔNIO BEZERRA.  VÍT...
# 68   LOCAL: RUA TIMBAÚBA, PICÍ.  ARMA APREENDIDA: R...
# 75   LOCAL: RUA PIAUÍ, PICÍ.  VEÍCULO: GOL CL 1.6 M...
# 82   LOCAL: RUA MARIA NEIVA, VILA VELHA.  VEÍCULO: ...
# 84   LOCAL: AV. MOZART PINHEIRO LUCENA, BARRA DO CE...
# 89   LOCAL: RUA I, QUINTINO CUNHA.ARMA APREENDIDA: ...
# 90   LOCAL:AV.CORONELCARVALHO,BARRADOCEARÁ.ARMAAPRE...
# 97   LOCAL: RUA CHILE, BELA VISTA.  VEÍCULO: NOVO G...
# 103  LOCAL: RUA JOARITA MENDES, QUINTINHO CUNHA.  V...
# 106  LOCAL: RUA K, VILA VELHA.  SUSPEITO: 1o - MENO...
# 119  LOCAL: AV. HILDEBRANDO DE MELO, BARRA DO CEARÁ...
# 127  LOCAL:RUAPARAMBU,VILAVELHA.VÍTIMAS:1oALBERTOM....
# 142  LOCAL: RUA BAHIA, PICI.  VEÍCULO: BROS ESD, VE...
# 144  LOCAL: RUA DRa SARA MESQUITA, PICI.  VEÍCULO: ...
# 147  LOCAL: RUA TULIPA, JARDIM IRACEMA.  VEÍCULO: C...
# 150  LOCAL: AV. INDEPENDÊNCIA, 0VILA VELHA.  ARMA A...
# 157  LOCAL: RUA MARIA CLARA, VILA VELHA.  MATERIAL ...
# 164  LOCAL: AV. CORONEL CARVALHO, JARDIM GUANABARA....
# 172  LOCAL: RUA PLANALTO PICI, PICI.  VÍTIMA: ANDER...
# 193  LOCAL: TRAVESSA FRANCISCO, PICI.  VEÍCULO: NXR...
# 194  LOCAL: RUA JOAQUIM FRANKLIN, ANTÔNIO BEZERRA.V...
# 197  LOCAL: RUA PEDRO MELO, ANTÔNIO BEZERRA.  VEÍCU...
# ..                                                 ...
# 208  LOCAL: RUA MARIA CLARA, VILA VELHA.SUSPEITO: H...
# 209  LOCAL: RUA VITÓRIA, HENRIQUE JORGE.VEÍCULO: ST...
# 215  LOCAL: RUA FROTA PESSOA, ANTÔNIO BEZERRA.  VEÍ...
# 218  LOCAL: RUA ANTÔNIO ARRUDA, VILA VELHA.  VEÍCUL...
# 250  LOCAL: RUA FRANCISCO MENDES, QUINTINO CUNHA.  ...
# 257  LOCAL: RUA DOS PRADOS, VILA VELHA.  VÍTIMA: SE...
# 274  LOCAL: RUA ESPÍRITO SANTO, PICI.  VEÍCULO: UNO...
# 277  LOCAL: RUA JACI, JARDIM IRACEMA. SUSPEITO: MEN...
# 284  LOCAL: RUA VALE COSTA, ANTÔNIO BEZERRA. SUSPEI...
# 298  LOCAL: RUA RAIMUNDO MESQUITA, VILA VELHA. VÍTI...
# 314  LOCAL: AV. J, VILA VELHA. SUSPEITOS: 1o HIAGO ...
# 317  LOCAL: RUA FRANCO ROCHA, PICI. VEÍCULO: UNO WA...
# 322  LOCAL: RUA DO CAMPO, VILA VELHA II. VEÍCULO: Y...
# 323  LOCAL: RUA PRESIDENTE PRUDENTE, ANTÔNIO BEZERR...
# 326  LOCAL: RUA ROSINHA SAMPAIO, QUINTINHO CUNHA. V...
# 329  LOCAL: AV INDEPENDÊCIA, VILA VELHA. CONDUTOR: ...
# 331  LOCAL: RUA PERNAMBUCO, PICI.VÍTIMA: JUCERLANDI...
# 335  LOCAL: RUA FLORENCIO DE ALENCAR, BARRA DO CEAR...
# 337  LOCAL: RUA TEODORO, VILA VELHA. VEÍCULO: PRISM...
# 339  LOCAL: RUA PERNAMBUCO, PICI. VEÍCULO: NXR150 B...
# 340  LOCAL: RUA RAIMUNDO MESQUITA, VILA VELHA.VEÍCU...
# 342  LOCAL: RUA RIO PARAGUAI, JARDIM IRACEMA.  VÍTI...
# 365  LOCAL:RUAJOSÉACIOLY,ÁLVAROWEYNE.VEÍCULO:CG160S...
# 409  LOCAL:AV.FLORÊNCIODEALENCAR,BARRADOCEARÁ.SUSPE...
# 415  LOCAL: RUA JOSÉ ANTÔNIO, PICI.  VEÍCULO: BROS ...
# 416  LOCAL: RUA OITO DE DEZEMBRO, ANTÔNIO BEZERRA. ...
# 420  LOCAL: RUA MARIA ILCA, VILA VELHA.  VEÍCULO: P...
# 445  LOCAL: AV. CORONEL CARVALHO, BARRA CEARÁ.  SUS...
# 490  LOCAL: RUA PLANALTO DO PICÍ, PICÍ.  VEÍCULO: S...
# 491  LOCAL: RUA DOM ALUÍSIO LOCHAIDER, VILA VELHA. ...
#
#                                          LOCAL:            BAIRRO  \
# 2                             RUA ALAGOAS, PICI              PICI
# 10                         RUA PERNAMBUCO, PICI              PICI
# 11                 RUA QUATRO DE DEZEMBRO, PICI              PICI
# 13                            RUA L, VILA VELHA        VILA VELHA
# 15            AV. MAJOR ASSIS, JARDIM GUANABARA  JARDIM GUANABARA
# 40              RUA PEDRO MELO, ANTONIO BEZERRA   ANTONIO BEZERRA
# 52               RUA RAIMUNDO CUNHA, VILA VELHA        VILA VELHA
# 54       RUA ANTONIETA CLOTILDE, JARDIM IRACEMA    JARDIM IRACEMA
# 55            RUA SAO DOMINGOS, ANTONIO BEZERRA   ANTONIO BEZERRA
# 68                           RUA TIMBAUBA, PICI              PICI
# 75                              RUA PIAUI, PICI              PICI
# 82                  RUA MARIA NEIVA, VILA VELHA        VILA VELHA
# 84   AV. MOZART PINHEIRO LUCENA, BARRA DO CEARA    BARRA DO CEARA
# 89                        RUA I, QUINTINO CUNHA    QUINTINO CUNHA
# 90              AV.CORONELCARVALHO,BARRADOCEARA      BARRADOCEARA
# 97                        RUA CHILE, BELA VISTA        BELA VISTA
# 103         RUA JOARITA MENDES, QUINTINHO CUNHA   QUINTINHO CUNHA
# 106                           RUA K, VILA VELHA        VILA VELHA
# 119     AV. HILDEBRANDO DE MELO, BARRA DO CEARA    BARRA DO CEARA
# 127                        RUAPARAMBU,VILAVELHA         VILAVELHA
# 142                             RUA BAHIA, PICI              PICI
# 144                 RUA DRa SARA MESQUITA, PICI              PICI
# 147                  RUA TULIPA, JARDIM IRACEMA    JARDIM IRACEMA
# 150              AV. INDEPENDENCIA, 0VILA VELHA       0VILA VELHA
# 157                 RUA MARIA CLARA, VILA VELHA        VILA VELHA
# 164      AV. CORONEL CARVALHO, JARDIM GUANABARA  JARDIM GUANABARA
# 172                     RUA PLANALTO PICI, PICI              PICI
# 193                    TRAVESSA FRANCISCO, PICI              PICI
# 194       RUA JOAQUIM FRANKLIN, ANTONIO BEZERRA   ANTONIO BEZERRA
# 197             RUA PEDRO MELO, ANTONIO BEZERRA   ANTONIO BEZERRA
# ..                                          ...               ...
# 208                 RUA MARIA CLARA, VILA VELHA        VILA VELHA
# 209                 RUA VITORIA, HENRIQUE JORGE    HENRIQUE JORGE
# 215           RUA FROTA PESSOA, ANTONIO BEZERRA   ANTONIO BEZERRA
# 218              RUA ANTONIO ARRUDA, VILA VELHA        VILA VELHA
# 250        RUA FRANCISCO MENDES, QUINTINO CUNHA    QUINTINO CUNHA
# 257                  RUA DOS PRADOS, VILA VELHA        VILA VELHA
# 274                    RUA ESPIRITO SANTO, PICI              PICI
# 277                    RUA JACI, JARDIM IRACEMA    JARDIM IRACEMA
# 284             RUA VALE COSTA, ANTONIO BEZERRA   ANTONIO BEZERRA
# 298           RUA RAIMUNDO MESQUITA, VILA VELHA        VILA VELHA
# 314                           AV. J, VILA VELHA        VILA VELHA
# 317                      RUA FRANCO ROCHA, PICI              PICI
# 322                 RUA DO CAMPO, VILA VELHA II     VILA VELHA II
# 323    RUA PRESIDENTE PRUDENTE, ANTONIO BEZERRA   ANTONIO BEZERRA
# 326        RUA ROSINHA SAMPAIO, QUINTINHO CUNHA   QUINTINHO CUNHA
# 329                 AV INDEPENDECIA, VILA VELHA        VILA VELHA
# 331                        RUA PERNAMBUCO, PICI              PICI
# 335    RUA FLORENCIO DE ALENCAR, BARRA DO CEARA    BARRA DO CEARA
# 337                     RUA TEODORO, VILA VELHA        VILA VELHA
# 339                        RUA PERNAMBUCO, PICI              PICI
# 340           RUA RAIMUNDO MESQUITA, VILA VELHA        VILA VELHA
# 342            RUA RIO PARAGUAI, JARDIM IRACEMA    JARDIM IRACEMA
# 365                   RUAJOSEACIOLY,ALVAROWEYNE       ALVAROWEYNE
# 409          AV.FLORENCIODEALENCAR,BARRADOCEARA      BARRADOCEARA
# 415                      RUA JOSE ANTONIO, PICI              PICI
# 416       RUA OITO DE DEZEMBRO, ANTONIO BEZERRA   ANTONIO BEZERRA
# 420                  RUA MARIA ILCA, VILA VELHA        VILA VELHA
# 445           AV. CORONEL CARVALHO, BARRA CEARA       BARRA CEARA
# 490                  RUA PLANALTO DO PICI, PICI              PICI
# 491       RUA DOM ALUISIO LOCHAIDER, VILA VELHA        VILA VELHA
#
#                                              SUSPEITO:  \
# 2                                                 nulo
# 10                                                nulo
# 11                                                nulo
# 13                            HOMENS NÃO IDENTIFICADOS
# 15                                    NÃO IDENTIFICADO
# 40                                                nulo
# 52                                                nulo
# 54   MENOR DE IDADE QUE FOI CONDUZIDO À DELEGACIA C...
# 55                                                nulo
# 68           FRANCISCO VALDEMIR ALVES AUGUSTO, 19 ANOS
# 75                                                nulo
# 82                                                nulo
# 84                                                nulo
# 89                   MONICLEY DE SOUSA CABRAL, 23 ANOS
# 90                  ADRIANOSALESRIBEIRO FILHO, 20 ANOS
# 97                                                nulo
# 103                                               nulo
# 106                                1o - MENOR DE IDADE
# 119                                               nulo
# 127                                               nulo
# 142                                               nulo
# 144                                               nulo
# 147                                               nulo
# 150                   ALISON GRIGÓRIO SANTANA, 23 ANOS
# 157                                               nulo
# 164                                               nulo
# 172                                               nulo
# 193                                               nulo
# 194                                               nulo
# 197                                               nulo
# ..                                                 ...
# 208                 HALLYSON DE MORAES DUARTE, 31 ANOS
# 209  FRANCISCO WAGNER EVANGELISTA DA SILVA, 29 ANOS...
# 215                                               nulo
# 218                                               nulo
# 250                                               nulo
# 257                                               nulo
# 274                                               nulo
# 277                                     MENOR DE IDADE
# 284         FRANCISCO CHARLES CARLOS DA SILVA, 21 ANOS
# 298                                   NÃO IDENTIFICADO
# 314                                               nulo
# 317                                               nulo
# 322                                               nulo
# 323                                               nulo
# 326                       LUCAS SANTANA BRAGA, 22 ANOS
# 329                                               nulo
# 331                                     MENOR DE IDADE
# 335                                               nulo
# 337                                               nulo
# 339                                               nulo
# 340                                               nulo
# 342                                   NÃO IDENTIFICADO
# 365                ANTÔNIOJOSÉSILVA\nMONTEIRO, 25 ANOS
# 409                                       MENORDEIDADE
# 415                                               nulo
# 416                                               nulo
# 420                                               nulo
# 445                                     MENOR DE IDADE
# 490                                               nulo
# 491                                               nulo
#
#                                               VEÍCULO:  \
# 2                                                 nulo
# 10                      YBR 125K, PRETA, 2008, NHY3676
# 11                NXR150 BROS ESD,PRETA, 2013, ORN5362
# 13                                                nulo
# 15                                                nulo
# 40                                                nulo
# 52                                            COBALT 1
# 54   MOTONETA, PRETA MARCA: TRAKK, 50Q9, CHASSI: 95...
# 55          YBR125 ED, PRATA, 2011/2011, PLACA OCJ1643
# 68                                                nulo
# 75                                            GOL CL 1
# 82             CLASSIC LS, CINZA, 2013, PLACA: OIJ3718
# 84                                               GOL 1
# 89                                                nulo
# 90                                                nulo
# 97                                          NOVO GOL 1
# 103                                               nulo
# 106                                               nulo
# 119          CB 250F TWISTER, BRANCA, 2016, PMT5241-CE
# 127                                               nulo
# 142               BROS ESD, VERMELHA,15, PLACA PMC2975
# 144                                            SIENA 1
# 147                  CLASSIC LS, PRETA, 12, PEJ5237-PE
# 150                                               nulo
# 157                                               nulo
# 164  YBR125 FACTOR ED, VERMELHA, 14/15, PLACA: PMF6...
# 172                                               nulo
# 193               NXR150 BROS ES, 2009, PRETA, HXA1166
# 194             NXR150 BROS MIX KS, PRETA, 10, NUY9326
# 197               CG 125 FAN ES, 11/12, PRETA, OIO8651
# ..                                                 ...
# 208                                               nulo
# 209                     START, PRETA, 2016, PME6933-CE
# 215                GOL 1000I, BRANCA, 1996, NBC7923-CE
# 218                BROS ESDD, BRANCA, 2016, PNL4357-CE
# 250          BROS, VERMELHA, 2016/2016, PLACA: PNU8457
# 257                                               nulo
# 274                          UNO, 2001, CINZA, HWZ2181
# 277                                               nulo
# 284                                               nulo
# 298                                               nulo
# 314                                               nulo
# 317                                          UNO WAY 1
# 322          YBR 125E, PRETA, 2002/2002, PLACA HWV2182
# 323       NXR160 BROS ESDD, PRETA, 2016, PLACA PNE6349
# 326                                               nulo
# 329                                               nulo
# 331                                               nulo
# 335                   YBR 125K, ROXA, 2004, HXB2345-CE
# 337                        PRISMA,CINZA,14, ORZ4787-CE
# 339              NXR150 BROS, PRETA, 10/11, NVA8906-CE
# 340                   FIESTA, PRATA, 13/14, ORL8850-CE
# 342                                               nulo
# 365         CG160START,VERMELHA,16/17,PLACA:PNH0641-CE
# 409                                               nulo
# 415                     BROS ESDD,BRANCA,15,PMH1215-CE
# 416                     GOL CLI,CINZA,95/96,HVF5718-CE
# 420                                           PRISMA 1
# 445                                               nulo
# 490                                  SIENA ATTRACTIV 1
# 491       GOL SPECIAL, BRANCO, 2002, PLACA: AKB4826-CE
#
#                                VÍTIMA:   ...   MATERIAL APREENDIDO:  \
# 2                                 nulo   ...                   nulo
# 10                                nulo   ...                   nulo
# 11                                nulo   ...                   nulo
# 13                          JONATHAN B   ...                   nulo
# 15   SEXO MASCULINO, SEM IDENTIFICAÇÃO   ...                   nulo
# 40                                nulo   ...                   nulo
# 52                                nulo   ...                   nulo
# 54                           CLAUDIO G   ...                   nulo
# 55                          WALBERTH B   ...                   nulo
# 68                                nulo   ...                   nulo
# 75                                nulo   ...                   nulo
# 82                                nulo   ...                   nulo
# 84                                nulo   ...                   nulo
# 89                                nulo   ...                   nulo
# 90                                nulo   ...                   nulo
# 97                                nulo   ...                   nulo
# 103                             ALAN M   ...                   nulo
# 106                               nulo   ...                   nulo
# 119                               nulo   ...                   nulo
# 127                               nulo   ...                   nulo
# 142                               nulo   ...                   nulo
# 144                               nulo   ...                   nulo
# 147                               nulo   ...                   nulo
# 150                               nulo   ...                   nulo
# 157                               nulo   ...      MACONHA E COCAÍNA
# 164                               nulo   ...                   nulo
# 172                         ANDERSON S   ...                   nulo
# 193                               nulo   ...                   nulo
# 194                               nulo   ...                   nulo
# 197                               nulo   ...                   nulo
# ..                                 ...   ...                    ...
# 208                               nulo   ...                   nulo
# 209                               nulo   ...                   nulo
# 215                               nulo   ...                   nulo
# 218                               nulo   ...                   nulo
# 250                               nulo   ...                   nulo
# 257  SEXO MASCULINO, SEM IDENTIFICAÇÃO   ...                   nulo
# 274                               nulo   ...                   nulo
# 277                               nulo   ...                   nulo
# 284                               nulo   ...                   nulo
# 298                          ANTÔNIO A   ...                   nulo
# 314                               nulo   ...                   nulo
# 317                               nulo   ...                   nulo
# 322                               nulo   ...                   nulo
# 323                               nulo   ...                   nulo
# 326                         RAIMUNDO N   ...                   nulo
# 329                               nulo   ...                   nulo
# 331                      JUCERLANDIO F   ...                   nulo
# 335                               nulo   ...                   nulo
# 337                               nulo   ...                   nulo
# 339                               nulo   ...                   nulo
# 340                               nulo   ...                   nulo
# 342   SEXO MASCULINO, NÃO IDENTIFICADO   ...                   nulo
# 365                               nulo   ...                   nulo
# 409                               nulo   ...                   nulo
# 415                               nulo   ...                   nulo
# 416                               nulo   ...                   nulo
# 420                               nulo   ...                   nulo
# 445                               nulo   ...                   nulo
# 490                               nulo   ...                   nulo
# 491                               nulo   ...                   nulo
#
#          PLACA: VÍTIMAS LESIONADAS:  \
# 2          nulo                nulo
# 10         nulo                nulo
# 11         nulo                nulo
# 13         nulo                nulo
# 15         nulo                nulo
# 40         nulo                nulo
# 52         nulo                nulo
# 54         nulo                nulo
# 55         nulo                nulo
# 68         nulo                nulo
# 75   HVM2282-CE                nulo
# 82      OIJ3718                nulo
# 84      OHY0783                nulo
# 89         nulo                nulo
# 90         nulo                nulo
# 97         nulo                nulo
# 103        nulo                nulo
# 106        nulo                nulo
# 119        nulo                nulo
# 127        nulo                nulo
# 142        nulo                nulo
# 144        nulo                nulo
# 147        nulo                nulo
# 150        nulo                nulo
# 157        nulo                nulo
# 164  PMF6860-CE                nulo
# 172        nulo                nulo
# 193        nulo                nulo
# 194        nulo                nulo
# 197        nulo                nulo
# ..          ...                 ...
# 208        nulo                nulo
# 209        nulo                nulo
# 215        nulo                nulo
# 218        nulo                nulo
# 250     PNU8457                nulo
# 257        nulo                nulo
# 274        nulo                nulo
# 277        nulo                nulo
# 284        nulo                nulo
# 298        nulo                nulo
# 314        nulo                nulo
# 317        nulo                nulo
# 322        nulo                nulo
# 323        nulo                nulo
# 326        nulo                nulo
# 329        nulo                nulo
# 331        nulo                nulo
# 335        nulo                nulo
# 337        nulo                nulo
# 339        nulo                nulo
# 340        nulo                nulo
# 342        nulo                nulo
# 365  PNH0641-CE                nulo
# 409        nulo                nulo
# 415        nulo                nulo
# 416        nulo                nulo
# 420        nulo                nulo
# 445        nulo                nulo
# 490  OEF9134-CE                nulo
# 491  AKB4826-CE                nulo
#
#                                             SUSPEITOS: HORA MINUTO      DATA  \
# 2                          NADA FOI INFORMADO NO LOCAL   13     21  01/02/17
# 10                               DOIS MENORES DE IDADE   12     10  01/02/17
# 11                                                nulo   13     36  01/02/17
# 13                                                nulo   11     09  02/02/17
# 15                                                nulo   21     52  02/02/17
# 40                                                nulo   16     07  02/02/17
# 52                                                nulo   08     46  03/02/17
# 54                                                nulo   16     08  03/02/17
# 55                                                nulo   19     10  03/02/17
# 68                                                nulo   22     49  04/02/17
# 75                                                nulo   06     42  04/02/17
# 82                                                nulo   17     10  04/02/17
# 84   1o – MENOR DE IDADE, 2o - KARLOS MAURÍCIO DE C...   22     23  04/02/17
# 89                                                nulo   19     24  05/02/17
# 90                                                nulo   21     21  05/02/17
# 97                                                nulo   13     01  05/02/17
# 103                                   NÃO IDENTIFICADO   13     30  06/02/17
# 106                                               nulo   07     08  06/02/17
# 119                                               nulo   14     10  06/02/17
# 127                  1oGABRIELTEIXEIRADEAMAURIM,19ANOS   05     46  07/02/17
# 142                                               nulo   13     31  07/02/17
# 144                                               nulo   15     43  07/02/17
# 147                                               nulo   20     10  07/02/17
# 150                                               nulo   10     41  08/02/17
# 157  1o - EDI JOSÉ ALVES BONFIM, 21 ANOS, 2o - LEON...   21     12  08/02/17
# 164                                               nulo   14     54  08/02/17
# 172                        NADA FOI INFORMADO NO LOCAL   02     28  09/02/17
# 193                                               nulo   13     51  09/02/17
# 194       1o ANTÔNIO DEONILSON SOUS RODRIGUES, 24 ANOS   15     53  09/02/17
# 197                                               nulo   20     56  09/02/17
# ..                                                 ...  ...    ...       ...
# 208                                               nulo   18     37  11/02/17
# 209                                               nulo   20     27  11/02/17
# 215                                               nulo   17     14  11/02/17
# 218                                               nulo   19     01  11/02/17
# 250                                               nulo   15     29  12/02/17
# 257                                  NÃO IDENTIFICADOS   01     08  14/02/17
# 274                                               nulo   14     20  14/02/17
# 277                                               nulo   20     27  14/02/17
# 284                                               nulo   11     32  15/02/17
# 298                                               nulo   16     32  16/02/17
# 314                      1o HIAGO SILVA VIANA, 20 ANOS   14     52  17/02/17
# 317                                               nulo   08     59  17/02/17
# 322                                               nulo   18     07  17/02/17
# 323                                               nulo   18     47  17/02/17
# 326                                               nulo   12     06  18/02/17
# 329                                               nulo   02     31  18/02/17
# 331                                               nulo   15     24  18/02/17
# 335                                               nulo   02     08  18/02/17
# 337                                               nulo   08     47  18/02/17
# 339                                               nulo   17     21  18/02/17
# 340                                               nulo   17     27  18/02/17
# 342                                               nulo   01     18  19/02/17
# 365                                               nulo   00     12  20/02/17
# 409                                               nulo   11     32  23/02/17
# 415                                               nulo   10     38  23/02/17
# 416                                               nulo   11     00  23/02/17
# 420                                               nulo   15     01  23/02/17
# 445                                               nulo   12     27  25/02/17
# 490                                               nulo   13     11  28/02/17
# 491                                               nulo   19     40  28/02/17
#
#      LATITUDE  LONGITUDE CLUSTER
# 2   -3.757314 -38.573171       3
# 10  -3.752435 -38.577180       3
# 11  -3.749389 -38.581202       3
# 13  -3.716034 -38.605936       3
# 15  -3.723071 -38.590884       3
# 40  -3.744029 -38.591001       3
# 52  -3.717417 -38.608634       3
# 54  -3.717120 -38.583955       3
# 55  -3.736400 -38.591150       3
# 68  -3.754962 -38.570867       3
# 75  -3.752470 -38.572041       3
# 82  -3.710241 -38.602599       3
# 84  -3.718734 -38.595881       3
# 89  -3.724800 -38.600228       3
# 90  -3.716786 -38.588176       3
# 97  -3.747433 -38.566637       3
# 103 -3.728005 -38.596738       3
# 106 -3.715305 -38.605295       3
# 119 -3.713148 -38.588122       3
# 127 -3.715751 -38.592759       3
# 142 -3.750804 -38.567658       3
# 144 -3.750792 -38.581942       3
# 147 -3.715898 -38.580078       3
# 150 -3.725909 -38.594508       3
# 157 -3.724882 -38.590050       3
# 164 -3.724689 -38.585955       3
# 172 -3.752557 -38.579902       3
# 193 -3.748980 -38.584197       3
# 194 -3.742928 -38.591287       3
# 197 -3.744029 -38.591001       3
# ..        ...        ...     ...
# 208 -3.724882 -38.590050       3
# 209 -3.753462 -38.582350       3
# 215 -3.738373 -38.592775       3
# 218 -3.716878 -38.593072       3
# 250 -3.730243 -38.593148       3
# 257 -3.711896 -38.604983       3
# 274 -3.753446 -38.568499       3
# 277 -3.716982 -38.585522       3
# 284 -3.743630 -38.588787       3
# 298 -3.710302 -38.606390       3
# 314 -3.716448 -38.598284       3
# 317 -3.754589 -38.580701       3
# 322 -3.715317 -38.603205       3
# 323 -3.737968 -38.594006       3
# 326 -3.725072 -38.594518       3
# 329 -3.725909 -38.594508       3
# 331 -3.752435 -38.577180       3
# 335 -3.710775 -38.585471       3
# 337 -3.720113 -38.589659       3
# 339 -3.752435 -38.577180       3
# 340 -3.710302 -38.606390       3
# 342 -3.723963 -38.584131       3
# 365 -3.735238 -38.592250       3
# 409 -3.710775 -38.585471       3
# 415 -3.747454 -38.584090       3
# 416 -3.745827 -38.587962       3
# 420 -3.712929 -38.606864       3
# 445 -3.716786 -38.588176       3
# 490 -3.752557 -38.579902       3
# 491 -3.714491 -38.596907       3
#
# [61 rows x 23 columns]

# %% [markdown]
# ### Uma análise sobre as 5 ocorrências mais comuns

# %%
crime_types = regiao_3_detalhe[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = regiao_3_detalhe[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5 = all_crime_types.head(5)
crimes_top_5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes na região 3')
plt.xlabel('Número de crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 horários com mais ocorrências em fevereiro

# %%
horas_mes = df_fevereiro.HORA.value_counts()
horas_mes_top10 = horas_mes.head(10)

# %%
horas_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Crimes por hora (Fev 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 5 horários com mais ocorrências na região 3 (região com mais ocorrências em fevereiro)

# %%
crime_hours = regiao_3_detalhe[['HORA']]
crime_hours_total = crime_hours.groupby('HORA').size()
crime_hours_counts = regiao_3_detalhe[['HORA']].groupby('HORA').sum()
crime_hours_counts['TOTAL'] = crime_hours_total
all_hours_types = crime_hours_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_hours_types.head(5)
# Out:
#       TOTAL
# HORA
# 13        7
# 15        5
# 14        4
# 20        4
# 19        4

# %%
all_hours_types_top5 = all_hours_types.head(5)
all_hours_types_top5.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 crimes por hora na região 3')
plt.xlabel('Número de ocorrências')
plt.ylabel('Hora do dia')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Filtro dos 10 bairros com mais ocorrências em fevereiro

# %%
crimes_mes = df_fevereiro.BAIRRO.value_counts()
crimes_mes_top10 = crimes_mes.head(10)

# %%
crimes_mes_top10.plot(kind='barh', figsize=(11,4), color='#3f3fff')
plt.title('Top 10 Bairros com mais crimes (Fev 2017)')
plt.xlabel('Número de ocorrências')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### O Bairro com o maior número de ocorrências em fevereiro foi o Passaré

# %% [markdown]
# ### Vamos agora ver de forma mais detalhadas quais foram estes crimes

# %%
passare = df_fevereiro[df_fevereiro['BAIRRO'] == 'PASSARE']
crime_types = passare[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = passare[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes no Passaré')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Os 5 bairros mais comuns na região 3

# %%
crime_types_bairro = regiao_3_detalhe[['BAIRRO']]
crime_type_total_bairro = crime_types_bairro.groupby('BAIRRO').size()
crime_type_counts_bairro = regiao_3_detalhe[['BAIRRO']].groupby('BAIRRO').sum()
crime_type_counts_bairro['TOTAL'] = crime_type_total_bairro
all_crime_types_bairro = crime_type_counts_bairro.sort_values(by='TOTAL', ascending=False)

# %%
crimes_top_5_bairro = all_crime_types_bairro.head(5)
crimes_top_5_bairro.plot(kind='barh', figsize=(11,3), color='#3f3fff')
plt.title('Top 5 bairros na região 3')
plt.xlabel('Quantidade')
plt.ylabel('Bairro')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# ### Análise sobre o bairro Vila Velha

# %%
vila_velha = df_fevereiro[df_fevereiro['BAIRRO'] == 'VILA VELHA']
crime_types = vila_velha[['NATUREZA DA OCORRÊNCIA']]
crime_type_total = crime_types.groupby('NATUREZA DA OCORRÊNCIA').size()
crime_type_counts = vila_velha[['NATUREZA DA OCORRÊNCIA']].groupby('NATUREZA DA OCORRÊNCIA').sum()
crime_type_counts['TOTAL'] = crime_type_total
all_crime_types = crime_type_counts.sort_values(by='TOTAL', ascending=False)

# %%
all_crime_tipos_5 = all_crime_types.head(5)
all_crime_tipos_5.plot(kind='barh', figsize=(15,4), color='#3f3fff')
plt.title('Top 5 crimes na Vila Velha')
plt.xlabel('Número de Crimes')
plt.ylabel('Crime')
plt.tight_layout()
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
